# %%
import numpy as np
import pandas as pd
import scipy
import scipy.stats
import matplotlib.pyplot as plt
# %matplotlib inline
from ggplot import *
# for maps
from mapboxgl.utils import *
from mapboxgl.viz import *
import geojson
# for text analysis
from google.cloud import language
from google.cloud.language import enums
from google.cloud.language import types
from inflector import Inflector, English

# %%
file_path = './camb-pb-data/Participatory_Budgeting_Ideas_Submitted_by_Community_Members.csv'
pb_data = pd.read_csv(file_path)

# %%
pb_data.head()
# Out:
#                         PB Cycle Idea #                       Committee  \
# 0  PB1 (October 2014-April 2015)     C1  Culture & Community Facilities
# 1  PB1 (October 2014-April 2015)     C2  Culture & Community Facilities
# 2  PB1 (October 2014-April 2015)     C3  Culture & Community Facilities
# 3  PB1 (October 2014-April 2015)     C4  Culture & Community Facilities
# 4  PB1 (October 2014-April 2015)     C5  Culture & Community Facilities
#
#                                        Project Title  \
# 0  Renovate the O'Connell Library; including the ...
# 1            New furniture for the O'Connell Library
# 2  Renovate the Cambridge Public Library branches...
# 3                          Main Library improvements
# 4                      Improvements to all libraries
#
#                                  Project Description  \
# 0  This is needed because the library is a very a...
# 1  The library needs new furniture and maybe a pl...
# 2  The Main Library is great, but many branches a...
# 3  1. Free parking.  2. Paid parking to be longer...
# 4      More computers.  Tax forms.  Tool check out.
#
#                                       Project Status Idea Submitter  \
# 0  This project made it to the ballot, but didn't...            Yan
# 1  This project made it to the ballot, but didn't...         Keniya
# 2  Renovations for the O'Connell Library branch m...           Rena
# 3  Budget Delegates did not move this idea forwar...   Martha Older
# 4  Budget Delegates did not rank this as a high p...   Martha Older
#
#                                             Location   Latitude  Longitude
# 0    48 Sixth Street\n(42.3704669999999, -71.084961)  42.370467 -71.084961
# 1  Otis Street\n(42.3704329999999, -71.0847749999...  42.370433 -71.084775
# 2    45 Pearl Street\n(42.363069, -71.1024699999999)  42.363069 -71.102470
# 3            449 Broadway\n(42.3741209, -71.1107166)  42.374121 -71.110717
# 4           Citywide\n(42.366956, -71.1058539999999)  42.366956 -71.105854

# %%
pb_data['Committee'] = pb_data['Committee'].apply(lambda x: x.strip())

# %%
pb_data.groupby('Committee').size()
# Out:
# Committee
# 'Bridge Builders                   76
# Community Resources                96
# Culture & Community Facilities    195
# Environment                        93
# Environment, Health & Safety      212
# Health, Environment & Safety      121
# Parks & Recreation                300
# Parks, Recreation & Education     113
# Streets, Sidewalks & Transit      170
# Streetsmarts                      582
# Youth & Education                  63
# Youth & Technology                 58
# dtype: int64

# %%
def rename_committees(committee):
    # code to rename committees
    if committee == 'Environment' or committee == 'Environment, Health & Safety' or committee == 'Health, Environment & Safety':
        return 'Environment, Health & Safety'
    elif committee == 'Parks & Recreation' or committee == 'Parks, Recreation & Education':
        return 'Parks, Recreation & Education'
    elif committee == 'Youth & Education' or committee == 'Youth & Technology':
        return 'Youth Education & Technology'
    elif committee == 'Streets, Sidewalks & Transit' or committee == 'Streetsmarts':
        return 'Streets, Sidewalks & Transit'
    elif committee == 'Culture & Community Facilities' or committee == 'Community Resources' or committee == '\'Bridge Builders':
        return 'Culture & Community'
    else:
        return committee

# %%
pb_data['Committee'] = pb_data['Committee'].apply(rename_committees)

# %%
pb_data['Committee'].value_counts(normalize=True)
# Out:
# Streets, Sidewalks & Transit     0.361712
# Environment, Health & Safety     0.204906
# Parks, Recreation & Education    0.198653
# Culture & Community              0.176527
# Youth Education & Technology     0.058201
# Name: Committee, dtype: float64

# %%
committee_groups = pb_data.groupby(['Committee'])
committees = committee_groups.size().to_frame(name='# of ideas submitted').reset_index()
committees.to_csv('camb-pb-data/committees.csv')

# %%
committees.head()
# Out:
#                        Committee  # of ideas submitted
# 0            Culture & Community                   367
# 1   Environment, Health & Safety                   426
# 2  Parks, Recreation & Education                   413
# 3   Streets, Sidewalks & Transit                   752
# 4   Youth Education & Technology                   121

# %%
cycle_groups = pb_data.groupby('PB Cycle')
cycles = cycle_groups.size().to_frame(name="# of ideas submitted").reset_index()
cycles.to_csv('camb-pb-data/cycles.csv')

# %%
cycles.head()
# Out:
#                         PB Cycle  # of ideas submitted
# 0  PB1 (October 2014-April 2015)                   380
# 1       PB2 (June-December 2015)                   540
# 2        PB3(June-December 2016)                   549
# 3        PB4(June-December 2017)                   610

# %%
pb_data.head()
# Out:
#                         PB Cycle Idea #            Committee  \
# 0  PB1 (October 2014-April 2015)     C1  Culture & Community
# 1  PB1 (October 2014-April 2015)     C2  Culture & Community
# 2  PB1 (October 2014-April 2015)     C3  Culture & Community
# 3  PB1 (October 2014-April 2015)     C4  Culture & Community
# 4  PB1 (October 2014-April 2015)     C5  Culture & Community
#
#                                        Project Title  \
# 0  Renovate the O'Connell Library; including the ...
# 1            New furniture for the O'Connell Library
# 2  Renovate the Cambridge Public Library branches...
# 3                          Main Library improvements
# 4                      Improvements to all libraries
#
#                                  Project Description  \
# 0  This is needed because the library is a very a...
# 1  The library needs new furniture and maybe a pl...
# 2  The Main Library is great, but many branches a...
# 3  1. Free parking.  2. Paid parking to be longer...
# 4      More computers.  Tax forms.  Tool check out.
#
#                                       Project Status Idea Submitter  \
# 0  This project made it to the ballot, but didn't...            Yan
# 1  This project made it to the ballot, but didn't...         Keniya
# 2  Renovations for the O'Connell Library branch m...           Rena
# 3  Budget Delegates did not move this idea forwar...   Martha Older
# 4  Budget Delegates did not rank this as a high p...   Martha Older
#
#                                             Location   Latitude  Longitude
# 0    48 Sixth Street\n(42.3704669999999, -71.084961)  42.370467 -71.084961
# 1  Otis Street\n(42.3704329999999, -71.0847749999...  42.370433 -71.084775
# 2    45 Pearl Street\n(42.363069, -71.1024699999999)  42.363069 -71.102470
# 3            449 Broadway\n(42.3741209, -71.1107166)  42.374121 -71.110717
# 4           Citywide\n(42.366956, -71.1058539999999)  42.366956 -71.105854

# %%
pb_by_category = committee_groups.size().to_frame(name='# of ideas').reset_index()

# %%
pb_by_location = pb_data.dropna(axis=0, how='any', subset=['Latitude', 'Longitude'])

# %%
# ideas by location
df_to_geojson(pb_by_location, filename='camb-pb-data/locations.geojson',
              properties=['Committee', 'PB Cycle'],
              lat='Latitude', lon='Longitude', precision=3)
# Out:
# /Users/alex/anaconda/envs/py3/lib/python3.6/site-packages/mapboxgl/utils.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[lon] = df[lon].round(precision)
# /Users/alex/anaconda/envs/py3/lib/python3.6/site-packages/mapboxgl/utils.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[lat] = df[lat].round(precision)
# {'feature_count': 1514,
#  'filename': 'camb-pb-data/locations.geojson',
#  'type': 'file'}

# %%
pb_data['Idea Submitter'].value_counts().head()
# Out:
# Martha Older                   69
# Anonymous                      30
# Russell Youth Center           29
# PB Assembly                    23
# CHA Summer Literacy Program    23
# Name: Idea Submitter, dtype: int64

# %% [markdown]
# Things I am interested in finding out:
# - categorize the ideas based on their content, more specific categories, rather than the few we have
# - break the interest of particular types of ideas (by category and the above) by year, see if trends exist for particular types of ideas
# - look at the influence of the minority, 69 (3.5% total) ideas presumably came from one person, that's a lot of influence (calculate how much based on any accepted proposals)

# %%
committee_and_cycle_groups = pb_data.groupby(['Committee', 'PB Cycle'])
committees_and_cycles = committee_and_cycle_groups.size().to_frame(name='# of ideas submitted').reset_index()
committees_and_cycles.to_csv('camb-pb-data/committees_and_cycles.csv')

# %%
ggplot(committees_and_cycles, aes(x='PB Cycle', y='# of ideas submitted', colour='Committee')) + geom_line()
# Out:
# <ggplot: (295723924)>

# %%
# Instantiates a client
client = language.LanguageServiceClient()

# %%
def entities_text(text):
    # Instantiates a plain text document.
    document = types.Document(
        content=text,
        type=enums.Document.Type.PLAIN_TEXT)

    # Detects entities in the document. You can also analyze HTML with:
    #   document.type == enums.Document.Type.HTML
    entities = client.analyze_entities(document).entities

    # entity types from enums.Entity.Type
    entity_type = ('UNKNOWN', 'PERSON', 'LOCATION', 'ORGANIZATION',
                   'EVENT', 'WORK_OF_ART', 'CONSUMER_GOOD', 'OTHER')

    entity_list = []
    for entity in entities:
        entity_list.append(entity.name)
    
    return ','.join(entity_list)

# %%
pb_data['Entities'] = pb_data['Project Title'].apply(entities_text)

# %%
pb_data.to_csv('camb-pb-data/pb_data_updated.csv')

# %%
# method for returning frequency counts from list
def get_freq_count(list_of_entities):
    word_freq = {}
    for row in list_of_entities:
        word_array = row.split(',')
        for word in word_array:
            word = inflector.singularize(word.lower().strip())
            if word in word_freq:
                word_freq[word] = word_freq[word] + 1
            else:
                word_freq[word] = 1
    return word_freq

# %%
total_freq_count = get_freq_count(pb_data['Entities'])
total_words_array = list(total_freq_count.keys())
total_word_counts_array = list(total_freq_count.values())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-173-5a1355a57334> in <module>()
# ----> 1 total_freq_count = get_freq_count(pb_data['Entities'])
#       2 total_words_array = list(total_freq_count.keys())
#       3 total_word_counts_array = list(total_freq_count.values())
#
# <ipython-input-172-0f75f25713be> in get_freq_count(list_of_entities)
#       5         word_array = row.split(',')
#       6         for word in word_array:
# ----> 7             word = inflector.singularize(word.lower().strip())
#       8             if word in word_freq:
#       9                 word_freq[word] = word_freq[word] + 1
#
# AttributeError: module 'inflector' has no attribute 'singularize'

# %%
word_usage_df = pd.DataFrame.from_dict({'Word': total_words_array, 'Count': total_word_counts_array})
word_usage_df.to_csv('camb-pb-data/word_freq.csv')

# %%
total_freq_count_by_cycle = {}
for name, group in cycle_groups:
    total_freq_count_by_cycle[name] = get_freq_count(group['Entities'])

# %%
total_freq_count_by_cycle['PB1 (October 2014-April 2015)']
# Out:
# {'a multitude of dog leash law signs': 1,
#  'a public park': 1,
#  'a raised intersection at trowbridge': 1,
#  'a-block': 1,
#  'acroos': 1,
#  'adult education': 1,
#  'ailwife': 1,
#  'air conditioner': 1,
#  'alewife t': 2,
#  'all': 1,
#  'ambulances': 2,
#  'amigos': 1,
#  'amigos middle school': 1,
#  'amigos school': 1,
#  'amount': 1,
#  'amphitheater': 1,
#  'anywhere': 1,
#  'apartments': 2,
#  'app': 4,
#  'architecture': 1,
#  'area': 6,
#  'area iv youth center': 1,
#  'areas': 7,
#  'arlington': 1,
#  'art': 2,
#  'art displays': 1,
#  'art walls': 1,
#  'artists': 1,
#  'ave': 3,
#  'ave-rt': 1,
#  'avenue': 1,
#  'b': 1,
#  'backboard': 1,
#  'banks street': 1,
#  'banners': 1,
#  'bars': 1,
#  'basins': 1,
#  'basket': 1,
#  'basketball courts': 1,
#  'bathroom': 1,
#  'bathrooms': 4,
#  'battery': 1,
#  'bbn': 1,
#  'beacon': 1,
#  'beacon st.': 1,
#  'belongings': 1,
#  'bench': 9,
#  'benches': 6,
#  'better public space': 1,
#  'bicycle': 1,
#  'bicycle parking': 1,
#  'bicycle paths': 1,
#  'bicycle signage': 1,
#  'bicyclists': 1,
#  'bike': 1,
#  'bike air pump': 1,
#  'bike lane': 7,
#  'bike lanes': 5,
#  'bike parking': 1,
#  'bike paths': 1,
#  'bike racks': 6,
#  'bikelane': 1,
#  "biker's ed": 1,
#  'bikers': 1,
#  'bikes': 2,
#  'biking': 1,
#  'billboard sign': 1,
#  'bioswales': 1,
#  'block parties': 1,
#  'boardman street': 1,
#  'body': 1,
#  'book houses': 1,
#  'bookmobile': 1,
#  'books': 2,
#  'bottom': 1,
#  'branch': 1,
#  'branches': 1,
#  'brattle/craigie/sparks street': 1,
#  'brick sidewalk': 1,
#  'bridge': 1,
#  'broadband system': 1,
#  'broadway': 4,
#  'build sidewalk': 1,
#  'building permit process': 1,
#  'buildings': 7,
#  'bulfinch place': 1,
#  'bus': 3,
#  'bus berths': 1,
#  'bus route': 1,
#  'bus shelter': 2,
#  'bus shelters': 2,
#  'bus stop shelters': 1,
#  'bus stops': 3,
#  'buses': 2,
#  'business district': 1,
#  'calling system': 1,
#  'camb': 1,
#  'camb/spring': 1,
#  'cambridge': 14,
#  'cambridge boat club': 1,
#  'cambridge city parks': 1,
#  'cambridge public library': 3,
#  'cambridge st. & hampshire st': 1,
#  'cambridge street': 3,
#  'cambridge streets': 1,
#  'cambridgeport': 1,
#  'cambridgeport school': 1,
#  'camera': 1,
#  'capacity': 1,
#  'capital idea': 1,
#  'capital improvement ideas': 1,
#  'car': 1,
#  'car lengths': 1,
#  'career resources': 1,
#  'caregive': 1,
#  'carlisle': 1,
#  'cars': 1,
#  'cdd': 1,
#  'centanni park': 1,
#  'center': 1,
#  'central': 1,
#  'central sq': 1,
#  'central square': 8,
#  'central square branch library': 1,
#  'chairs': 4,
#  'changes': 1,
#  'charles river': 3,
#  'charles sumner': 1,
#  'checkout': 1,
#  'children': 4,
#  'citizen parks': 1,
#  'city': 11,
#  'city hall': 5,
#  'city hall lawn': 1,
#  'city line': 1,
#  'city lot': 2,
#  'city manager': 1,
#  'city specialty trucks': 1,
#  'city/institutions': 1,
#  'civil war': 1,
#  'clarendon ave': 1,
#  'class': 1,
#  'classes': 1,
#  'collection': 1,
#  'community': 1,
#  'community availability': 1,
#  'community bulletin board': 1,
#  'community bulletin boards': 1,
#  'community garden': 2,
#  'community gardens': 2,
#  'community learning center': 2,
#  'community photo booth': 1,
#  'community repair': 1,
#  'community solar': 1,
#  'community space': 3,
#  'community spaces ground level': 1,
#  'commuter rail tracks': 1,
#  'concord': 1,
#  'concrete ping-pong': 1,
#  'conditions': 1,
#  'congestion pricing': 1,
#  'conjunction': 1,
#  'cookery school': 1,
#  'cooks': 1,
#  'coop': 1,
#  'corner': 3,
#  'corporal burns': 1,
#  'council': 1,
#  'cps': 1,
#  'cross': 1,
#  'cross town': 1,
#  'cross walk': 1,
#  'crossing': 1,
#  'crossing guard': 1,
#  'crosswalk': 4,
#  'crosswalk lights': 1,
#  'crosswalk warning lights': 1,
#  'crosswalk warning sign': 1,
#  'crosswalks': 3,
#  'curb extension': 1,
#  'curtains': 1,
#  'cycle track': 4,
#  'cycles': 1,
#  'dance': 1,
#  'danehy': 2,
#  'danehy park': 1,
#  'daniel f. burns': 1,
#  'dawes island': 1,
#  'day center': 1,
#  'daylighting': 1,
#  'developer': 1,
#  'digitize property files': 1,
#  'district': 1,
#  'district geothermal': 1,
#  'dj station': 1,
#  'dog areas': 1,
#  'dog park': 2,
#  'dog parks': 1,
#  'dogs': 2,
#  'donnelly field': 1,
#  'dpw': 1,
#  'dpw yard': 1,
#  'drinking fountains': 1,
#  'drivers': 1,
#  'drunks': 1,
#  'dugouts': 1,
#  'eagle sculpture': 1,
#  'east cambridge': 1,
#  'education bike signage': 1,
#  'educational park': 1,
#  'electricity production': 1,
#  'elementary schools': 1,
#  'elements': 1,
#  'ellery': 1,
#  'elm': 1,
#  'emergency response': 1,
#  'energy efficiency upgrades': 1,
#  'entrance': 2,
#  'entrances': 2,
#  'equipment for the youth centers': 1,
#  'establishments': 1,
#  'events': 1,
#  'exercise equipment': 1,
#  'experiences': 1,
#  'facilities': 1,
#  'facility': 1,
#  'families': 3,
#  'fawcett': 1,
#  'fayerweather street': 1,
#  'fee': 1,
#  'fence': 3,
#  'fern': 1,
#  'fern street': 1,
#  'field & fern': 1,
#  'field conditions': 2,
#  'filter': 1,
#  'fire dept': 1,
#  'fire lane': 1,
#  'fire trucks': 2,
#  'fitness park': 1,
#  'fitness stations': 1,
#  'fixtures': 1,
#  'flag': 1,
#  'fletcher maynard academy': 1,
#  'floor': 2,
#  'flowers/planters': 1,
#  'fma': 1,
#  'football field': 1,
#  'footbridge': 1,
#  'foundry building': 2,
#  'fountain': 1,
#  'fresh pond': 4,
#  'fresh pond circle': 1,
#  'fresh pond golf course': 1,
#  'fresh pond parkway': 2,
#  'fresh pond pkwy': 1,
#  'freshpond': 1,
#  'front': 5,
#  'fulmore park': 1,
#  'fund summertime activities': 1,
#  'funding': 1,
#  'furniture': 2,
#  'gaming spaces': 1,
#  'garden': 4,
#  'garden beds': 1,
#  'garfield street': 1,
#  'gates': 2,
#  'gift': 1,
#  'glacken field': 1,
#  'gordon ramsey': 1,
#  'graciously allow the public': 1,
#  'graffiti': 1,
#  'grand boulevard': 1,
#  'grand junction': 1,
#  'grass': 1,
#  'grill': 1,
#  'groups': 1,
#  'guard rail': 1,
#  'guard rails': 1,
#  'gyms': 1,
#  'h&r block': 1,
#  'hampshire': 3,
#  'hancock street': 1,
#  'harvard': 4,
#  'harvard bridge': 1,
#  'harvard plaza': 1,
#  'harvard square': 3,
#  'harvard street': 1,
#  'harvard t station': 1,
#  'headhouse': 1,
#  'health': 1,
#  'health curriculum': 1,
#  'heave': 1,
#  'help': 1,
#  'holes': 1,
#  'holiday lighting program': 1,
#  'homeless': 2,
#  'homeless shelter': 1,
#  'housing': 7,
#  'hoyt field': 1,
#  'huron ave': 2,
#  'idea': 2,
#  'impact': 1,
#  'improvements': 4,
#  'income': 1,
#  'indoor playspace': 1,
#  'information': 2,
#  'infrastructure': 1,
#  'inman sq': 2,
#  'inman square': 9,
#  'install bathrooms': 1,
#  'install sidewalks': 1,
#  'installation': 1,
#  'intersection': 9,
#  'intersections': 2,
#  'islands': 1,
#  'items': 1,
#  'jackson gardens': 1,
#  "jerry's pond": 1,
#  'jfk': 1,
#  'kids': 1,
#  'kiosk': 1,
#  'land': 2,
#  'lanes': 3,
#  'laptops': 1,
#  'larch': 1,
#  'larch park': 1,
#  'lawn': 1,
#  'leash dog park': 1,
#  'length': 1,
#  'lengths': 1,
#  'leslie university porter square': 1,
#  'libraries': 2,
#  'library': 2,
#  'library branch': 1,
#  'library improvements': 1,
#  'library park': 1,
#  'life': 1,
#  'light': 3,
#  'light sensors': 1,
#  'lighting': 11,
#  'lightings': 1,
#  'lights': 6,
#  'lincoln way': 1,
#  'line': 2,
#  'line street': 2,
#  'linear park': 2,
#  'liquor bottles': 1,
#  'living light': 1,
#  'loan fund': 1,
#  'location': 1,
#  'loop': 1,
#  'lot': 1,
#  'lots': 3,
#  'lowell park': 1,
#  'magazine': 1,
#  'magazine beach': 1,
#  'magazine beach park': 1,
#  'magazine street': 1,
#  'main library': 2,
#  'makerspace': 2,
#  'map': 1,
#  'mapping buildings': 1,
#  'markings': 1,
#  'mass': 5,
#  'mass ave': 5,
#  'mass ave & garden st': 1,
#  'mass ave & western ave': 1,
#  'mass ave median strips': 1,
#  'massachusetts': 1,
#  'material': 1,
#  'median': 1,
#  'medians': 1,
#  'meet': 1,
#  'meeting': 1,
#  'meetings': 1,
#  'memorial drive': 1,
#  'memorial drive section': 1,
#  'meters': 1,
#  'mid-cambridge': 1,
#  'middle': 1,
#  'mine': 1,
#  'mit alumnus': 1,
#  'mlk school': 1,
#  'money': 1,
#  'money matters': 1,
#  'monument': 1,
#  'more': 1,
#  'motor toys': 1,
#  'movies': 1,
#  'mural': 1,
#  'music': 2,
#  'music space': 1,
#  'n': 1,
#  'name': 1,
#  'needs': 1,
#  'neglected public space': 1,
#  'neighbor person': 1,
#  'neighborhood': 2,
#  'neighborhood discussions': 1,
#  'neighborhood library': 1,
#  'neighborhood planning processes': 1,
#  'neighborhood sustainability': 1,
#  'neighborhoods': 1,
#  'neighborway': 1,
#  'newtowne court': 2,
#  'night lighting': 1,
#  'nights': 1,
#  'norfolk street parking lot': 1,
#  'north cambridge': 3,
#  'north cambridge community garden': 1,
#  'number': 1,
#  "o'connell library": 2,
#  'on rindge ave.': 1,
#  'one': 2,
#  'ones': 1,
#  'onsite signage': 1,
#  'oppressive barrier': 1,
#  'options': 2,
#  'organizations': 1,
#  'panels': 2,
#  'paper': 1,
#  'paperwork': 1,
#  'parents': 1,
#  'park': 4,
#  'park entrance': 1,
#  'park renovations': 1,
#  'park seating': 1,
#  'park users': 1,
#  'parking': 5,
#  'parking lot': 2,
#  'parking lots': 1,
#  'parking meters': 3,
#  'parking permits': 1,
#  'parking spaces': 1,
#  'parks': 3,
#  'parkway': 1,
#  'part': 2,
#  'participation': 1,
#  'partner': 1,
#  'passes': 1,
#  'path': 3,
#  'pathways': 1,
#  'pavement': 1,
#  'paving': 1,
#  'peabody parks school': 1,
#  'peabody school park': 1,
#  'peace': 1,
#  'pedestrian': 1,
#  'pedestrian intersections': 1,
#  'pedestrian mall': 1,
#  'pedestrian problem': 1,
#  'pedestrian push button signal': 1,
#  'pemberton': 1,
#  'people': 2,
#  'performance venue': 1,
#  'performances': 1,
#  'periphery': 1,
#  'permit application process': 1,
#  'persons': 1,
#  'pets': 1,
#  'phone calls': 1,
#  'phone charging stations': 1,
#  'piano vents': 1,
#  'picnic benches': 1,
#  'ping pong': 1,
#  'place': 1,
#  'place generators': 1,
#  'places': 1,
#  'planters': 1,
#  'play area': 2,
#  'play structures': 1,
#  'play/climbing areas': 1,
#  'playground': 8,
#  'playground/park': 1,
#  'playgrounds': 3,
#  'plays': 1,
#  'pods': 1,
#  'police': 2,
#  'police presentations': 1,
#  'porter': 1,
#  'porter square': 1,
#  'porter square galleria': 1,
#  'porter t station': 1,
#  'portion': 1,
#  'post office': 1,
#  'practice rooms': 1,
#  'priority traffic signals': 1,
#  'process': 1,
#  'program': 1,
#  'project': 2,
#  'properties': 1,
#  'prospect street': 2,
#  'protection': 1,
#  'pruning': 1,
#  'public': 1,
#  'public realm': 1,
#  'rain gardens': 1,
#  'raymond park': 3,
#  're-design': 1,
#  're-do': 1,
#  're-paint': 1,
#  'recording': 1,
#  'recycling': 3,
#  'recycling wastebaskets': 1,
#  'red line': 1,
#  'redesign': 1,
#  'redesign intersection': 1,
#  'relationships': 1,
#  'renovate playground': 1,
#  'repair flooding problems': 1,
#  'repair potholes': 1,
#  'repave sherman st': 1,
#  'replacement': 1,
#  'replacement bus shelter': 1,
#  'residents': 3,
#  'resource center': 1,
#  'responsibility': 1,
#  'restore parkland': 1,
#  'restroom': 2,
#  'restrooms': 4,
#  'rindge ave': 1,
#  'rindge ave & comeau field': 1,
#  'river street': 1,
#  'riverside park': 2,
#  'road': 2,
#  'road lines': 1,
#  'road signage': 1,
#  'roads': 2,
#  'roof gardens': 1,
#  'rooms': 1,
#  'roseland street': 1,
#  'routes': 1,
#  'rubber bench seats': 1,
#  'rug': 1,
#  'rush houes': 1,
#  'russell field': 3,
#  'russell field house': 1,
#  'sacramento field': 1,
#  'safety': 3,
#  'safety lights': 1,
#  'sale': 1,
#  'school': 3,
#  'school crossing guards': 1,
#  'school garden': 1,
#  'school lunch': 2,
#  'school lunch cooks': 1,
#  'school parks': 1,
#  'school playground': 1,
#  'school supplies': 1,
#  'schools': 3,
#  'screen': 1,
#  'sculpture': 1,
#  'sculptures': 1,
#  'seating': 2,
#  'security cameras': 2,
#  'senior': 1,
#  'senior center bathrooms': 1,
#  'senior citizens': 1,
#  'sennot park': 1,
#  'sennott park': 2,
#  'shading options': 1,
#  'shelter': 1,
#  'shelters': 3,
#  'sherman st': 1,
#  'sherman st.': 1,
#  'sherman street': 1,
#  'shopping center': 1,
#  'shopping plaza': 1,
#  'shower': 1,
#  'shower rooms': 2,
#  'side': 1,
#  'sidewalk': 5,
#  'sidewalks': 4,
#  'sign': 1,
#  'signage': 3,
#  'signals': 1,
#  'signgs': 1,
#  'signs': 4,
#  'sites': 1,
#  'slope': 1,
#  'smoking areas': 1,
#  'snow': 2,
#  'snowplowing sidewalks': 1,
#  'softball fields': 1,
#  'solar': 8,
#  'solar panels': 1,
#  'solution': 1,
#  'some': 1,
#  'sommerville': 1,
#  'space': 6,
#  'spaces': 3,
#  'species': 1,
#  'speed bumps': 2,
#  'squares': 1,
#  "st. john's church": 1,
#  'staff': 1,
#  'stairwell': 1,
#  'standing zone': 1,
#  'start-up': 1,
#  'statue': 1,
#  'stayfitcambridge': 1,
#  'stones': 1,
#  'stop sign': 1,
#  'store': 1,
#  'street': 6,
#  'street cleaning': 1,
#  'street lighting improvements': 1,
#  'street lights': 2,
#  'street performers': 1,
#  'street trees': 1,
#  'streets': 1,
#  'streetscape improvements': 1,
#  'structures': 2,
#  'student': 1,
#  'studio': 1,
#  'subways': 1,
#  'surface': 1,
#  'surface repair': 1,
#  'swimming pool': 1,
#  'swing set': 1,
#  'swings': 1,
#  't passes': 1,
#  't station': 1,
#  't stations': 2,
#  'tables': 5,
#  'tablets': 1,
#  'tax': 1,
#  'taxes': 1,
#  'teens': 1,
#  'tennis courts': 1,
#  'the ride': 1,
#  'theater': 1,
#  'things': 1,
#  'times': 1,
#  'timing': 1,
#  'tobin': 2,
#  'toilet': 1,
#  'tokyo': 1,
#  'tools': 4,
#  'topics': 1,
#  'tot': 1,
#  'tot lot/park': 1,
#  'tow trucks': 1,
#  'tracks': 3,
#  'traffic': 2,
#  'traffic calming': 2,
#  'traffic flow': 1,
#  'traffic garden': 2,
#  'traffic guard': 1,
#  'traffic light': 2,
#  'traffic light timing': 1,
#  'traffic light-corner': 1,
#  'traffic lights': 1,
#  'traffic rules': 1,
#  'traffic signals': 1,
#  'train stations': 1,
#  'train tracks': 1,
#  'training kitchen': 1,
#  'transportation': 2,
#  'trash barrel': 1,
#  'travel lane': 1,
#  'tree roots': 1,
#  'trees': 8,
#  'tremont': 1,
#  'tri corner': 1,
#  'trucks': 1,
#  'turf': 1,
#  'tv moniters': 1,
#  'twinkle lights': 1,
#  'upgrade': 1,
#  'use': 3,
#  'utility wires': 1,
#  'variety': 1,
#  'vassal lane': 2,
#  'vehicle emissions': 1,
#  'vehicles': 1,
#  'vellucci park': 1,
#  'vellucci plaza': 1,
#  'vest-pocket park': 1,
#  'video sign': 1,
#  'view': 1,
#  'volunteer gaps': 1,
#  'walden st.': 1,
#  'walden street': 2,
#  'walk signals': 1,
#  'walking': 2,
#  'walking trail guide': 1,
#  'walks': 1,
#  'warming': 1,
#  'water bottle fill stations': 1,
#  'water bubbler': 1,
#  'water feature': 1,
#  'water fountains': 1,
#  'way': 1,
#  'wayfinding': 1,
#  'wayfinding assessment': 1,
#  'ways': 1,
#  'webster ave': 2,
#  'western ave': 1,
#  'wetland': 2,
#  'white street': 1,
#  'whittemore avenue community garden': 1,
#  'wifi': 12,
#  'wind': 1,
#  'windsor': 2,
#  'winter fun': 1,
#  'wires': 2,
#  'wit': 1,
#  'woodland restoration project': 1,
#  'work': 1,
#  'youth center': 1}

# %%
total_freq_count_by_cycle['PB2 (June-December 2015)']
# Out:
# {'3d printers': 1,
#  '3rd street': 1,
#  '@': 1,
#  'aberdeen ave': 1,
#  'accessibility': 1,
#  'accident area': 1,
#  'accidents': 1,
#  'adults': 1,
#  'african american': 2,
#  'ages': 3,
#  'air polution': 1,
#  'alarms': 2,
#  'alewife': 4,
#  'alewife brook parkway': 1,
#  'alewife station': 2,
#  'alpine street': 1,
#  'american': 1,
#  'ames street': 1,
#  'amigos school': 1,
#  'amphitheater': 3,
#  'anderson memorial bridge': 1,
#  'apartments': 1,
#  'app': 4,
#  'area': 7,
#  'area 4': 1,
#  'area iv': 1,
#  'area iv youth center': 1,
#  'areas': 3,
#  'arlington': 1,
#  'arrow': 1,
#  'art': 2,
#  'art & play': 1,
#  'art displays': 1,
#  'art mural projects': 1,
#  'art murals': 1,
#  'art supplies': 1,
#  'artful gazebo': 1,
#  'artists': 1,
#  'arts council': 1,
#  'auburn street': 1,
#  'auburn streets': 1,
#  'auburn.': 1,
#  'auditorium': 1,
#  'ave': 3,
#  'avenue': 1,
#  'avenues': 1,
#  'baby changing stations': 1,
#  'backs': 1,
#  'baldwin school': 1,
#  'ballcourts': 1,
#  'barrier': 1,
#  'basketball court': 2,
#  'basketball courts': 2,
#  'basketball hoops': 1,
#  'bathroom': 2,
#  'bathrooms': 3,
#  'bbn': 1,
#  'beautification': 2,
#  'bedrooms': 1,
#  'bees': 1,
#  'belmont': 1,
#  'belmont st.': 1,
#  'bench': 1,
#  'bench-a-block': 1,
#  'benches': 5,
#  'bergin park tennis courts': 1,
#  'bicycle lane pavement markings': 1,
#  'bicycle path': 1,
#  'bicycling facilities': 1,
#  'bigelow': 1,
#  'bike': 1,
#  'bike corrals': 1,
#  'bike helmets': 1,
#  'bike infrastructure': 1,
#  'bike lane': 2,
#  'bike lane protectors': 1,
#  'bike lanes': 16,
#  'bike network': 1,
#  'bike parking': 1,
#  'bike parking lot': 1,
#  'bike path': 5,
#  'bike paths': 1,
#  'bike racks': 2,
#  'bike rentals': 1,
#  'bike route': 1,
#  'bike safety': 1,
#  'bike signals': 1,
#  'bike stands': 1,
#  'bike storage systems': 1,
#  'bike traffic lights': 1,
#  'bike travel': 1,
#  'bikers': 2,
#  'bikes': 4,
#  'bikeways': 1,
#  'biking lanes': 1,
#  'bird bath': 1,
#  'birds': 1,
#  'bldg': 1,
#  'block': 1,
#  'block parties': 1,
#  'boat dock': 1,
#  'bollards': 2,
#  'books': 2,
#  'booths': 1,
#  'boston': 1,
#  'bottle fill stations': 1,
#  'bottle fillers': 1,
#  'bottom': 1,
#  'boxes': 1,
#  'branch': 1,
#  'brattle square': 1,
#  'brattle st': 1,
#  'breastfeeding': 1,
#  'bricks': 1,
#  'bridge': 3,
#  'broadway': 3,
#  'bu': 1,
#  'bu bridge': 2,
#  'building': 3,
#  'building construction': 1,
#  'building transformation': 1,
#  'buildings': 9,
#  'bus': 3,
#  'bus arrival monitors': 1,
#  'bus shelter': 2,
#  'bus shelters': 2,
#  'bus stations': 1,
#  'bus stop': 2,
#  'bus stop signs': 1,
#  'bus stops': 6,
#  'bus stops citywide': 1,
#  'buses': 2,
#  'businesses': 1,
#  'butterfly garden': 2,
#  'c.h.a': 1,
#  'cable': 1,
#  'cadet platform pilot': 1,
#  'cafe': 1,
#  'cambr.': 1,
#  'cambridge': 30,
#  'cambridge carnival': 1,
#  'cambridge carnival intl. inc': 1,
#  'cambridge common': 1,
#  'cambridge community farm': 1,
#  'cambridge electric department': 1,
#  'cambridge public library': 2,
#  'cambridge st': 1,
#  'cameron & davis': 1,
#  'cameron & mass ave': 1,
#  'cameron ave': 2,
#  'capital': 1,
#  'car': 1,
#  'car parking app': 1,
#  'car traffic': 1,
#  'cards': 1,
#  'care': 1,
#  'cargo bike': 1,
#  'carparks': 1,
#  'carpet': 1,
#  'cars': 3,
#  'caspar': 1,
#  'ccsc': 1,
#  'cedar street': 1,
#  'cement': 1,
#  'census data': 1,
#  'center': 3,
#  'center kitchen': 1,
#  'central square': 7,
#  'central squares': 1,
#  'cha': 1,
#  'chain link fences': 1,
#  'chairs': 2,
#  'change signals': 1,
#  'charger benches': 1,
#  'charging stations': 3,
#  'charles': 1,
#  'charles river': 3,
#  'charlie': 1,
#  'charter schools': 1,
#  'chestnut': 1,
#  'child care': 1,
#  'children': 4,
#  'chinese': 1,
#  'cigarette butt receptacles': 1,
#  'cinder running track': 1,
#  'circuit training equipment': 1,
#  'cistern': 1,
#  'city': 14,
#  'city buildings': 3,
#  'city composting': 1,
#  'city diesel trucks': 1,
#  'city east': 1,
#  'city hall': 4,
#  'city parks': 2,
#  'city property': 1,
#  'city tree wells': 1,
#  'city trees': 1,
#  'city trucks': 1,
#  'city websites': 1,
#  'citywide bench program': 1,
#  'citywide senior center': 1,
#  'classes': 1,
#  'classrooms': 1,
#  'clement g. morgan park': 1,
#  'clement morgan historical marker': 1,
#  'clement park': 1,
#  'clothing exchange': 1,
#  'collins branch library': 1,
#  'collins library': 1,
#  'color porter': 1,
#  'color printers': 1,
#  'columbia st': 1,
#  'combination': 1,
#  'comeau field': 1,
#  'common': 1,
#  'communities': 1,
#  'community': 1,
#  'community boat house': 1,
#  'community bulletin boards': 1,
#  'community events': 1,
#  'community garden': 2,
#  'community gardens': 3,
#  'community learning center': 1,
#  'community learning kitchen': 1,
#  'community policing': 1,
#  'community repair': 1,
#  'community rooms': 1,
#  'composting toilets': 1,
#  'computer access': 1,
#  'computer centers': 1,
#  'computer lab': 1,
#  'computer science teachers': 1,
#  'computers': 2,
#  'concord ave': 1,
#  'concord avenue w': 1,
#  'condition': 1,
#  'condos': 1,
#  'construction activities': 1,
#  'contributions': 1,
#  'conveyor belts': 1,
#  'coolidge ave': 1,
#  'copying machine': 1,
#  'corner': 1,
#  'courts': 1,
#  'cps': 1,
#  'creation': 1,
#  'crls': 2,
#  'cross streets': 1,
#  'crossing guards': 1,
#  'crosswalk': 3,
#  'crosswalks': 3,
#  'curbcuts': 1,
#  'curbs': 1,
#  'curtains': 1,
#  'cvs': 1,
#  'cycle lanes': 1,
#  'cycle track': 2,
#  'cycle tracks': 2,
#  'cycletrack': 1,
#  'd': 1,
#  'daei': 1,
#  'dana park': 2,
#  'dance studio': 1,
#  'danehy': 5,
#  'danehy dog park': 2,
#  'danehy park': 9,
#  'danehy park playing fields': 1,
#  'davis': 1,
#  'day care': 1,
#  'defibrillators': 1,
#  'design competition': 1,
#  'digital arts education initiative': 1,
#  'directory': 1,
#  'discounts': 1,
#  'disgrace': 1,
#  'display art': 1,
#  'dna testing': 1,
#  'dog park': 5,
#  'dog parks': 1,
#  'dog recreation': 1,
#  'dog waste': 1,
#  'dog-waste': 1,
#  'dogs': 1,
#  "don't": 1,
#  'donnelly field': 1,
#  'door openers': 1,
#  'dpw': 2,
#  'dpw tool': 1,
#  'drinking water fountains': 1,
#  'dudley st': 1,
#  'duet wheelchair bicycle tandem system': 1,
#  'e-books': 1,
#  'east cambridge': 4,
#  'elderly': 2,
#  'electric motor assist': 1,
#  'electricity': 1,
#  'end': 1,
#  'energy': 3,
#  'entrance': 1,
#  'equipment': 2,
#  'ev chargers': 1,
#  'events': 3,
#  'everywhere': 1,
#  'exercise': 1,
#  'exercise class': 1,
#  'exercise equipment': 1,
#  'expand outdoor stretching & exercise equipment': 1,
#  'exterior': 1,
#  'eyesore': 1,
#  'families': 2,
#  'farmers market': 1,
#  'fencing': 2,
#  'fiber optic': 1,
#  'filling stations': 1,
#  'fire': 1,
#  'firehouse conditions': 1,
#  'first parish church': 1,
#  'first step street outreach': 1,
#  'fitchburg cutoff path': 1,
#  'fitness equipment': 1,
#  'fitness equipments': 1,
#  'fitness trail': 1,
#  'fletcher maynard academy': 1,
#  'flooding': 1,
#  'floor tiles': 1,
#  'floors': 1,
#  'flowering plants': 1,
#  'flowers': 2,
#  'font street signage': 1,
#  'food pantries': 1,
#  'food pantry program': 1,
#  'foot': 1,
#  'footpath cycle parking': 1,
#  'franklin street park': 1,
#  'fresh pond': 7,
#  'fresh pond circle': 1,
#  'fresh pond mall': 1,
#  'fresh pond parkway': 1,
#  'fresh pond reservation': 1,
#  'frisoli': 1,
#  'frisoli youth': 1,
#  'frisoli youth center': 2,
#  'frisoli youth center w': 1,
#  'frog pond': 1,
#  'front': 2,
#  'fruit trees': 1,
#  'funds': 1,
#  'game center': 1,
#  'game center/arcade': 1,
#  'games': 1,
#  'garbage': 1,
#  'garbage cans': 1,
#  'garbage collection': 1,
#  'garden': 3,
#  'garden street': 1,
#  'gately': 4,
#  'gately youth center': 1,
#  'gatorade fountains': 1,
#  'gerry': 1,
#  'glass enclosures': 1,
#  'glow': 1,
#  'golf': 2,
#  'graham': 1,
#  'grasses': 1,
#  'green': 1,
#  'green bike lanes': 1,
#  'green infrastructure': 2,
#  'green space': 1,
#  'green street': 1,
#  'greene rose park': 1,
#  'grid': 2,
#  'grills': 3,
#  'guardrail': 1,
#  'gym visit': 1,
#  'gyms': 1,
#  'haggerty school': 1,
#  'hampshire': 1,
#  'hancock': 1,
#  'handicap access': 1,
#  'harvard': 1,
#  'harvard sq': 1,
#  'harvard square': 4,
#  'harvard streets: windsor streetscape': 1,
#  'healing garden': 1,
#  'health': 1,
#  'health signs': 1,
#  'health youth local bank accounts': 1,
#  'heat lamps': 1,
#  'heattrack.com': 1,
#  'help': 1,
#  'heritage trail': 1,
#  'high school': 2,
#  'home': 1,
#  'homeless': 1,
#  'homeless population': 1,
#  'homeless shelter': 2,
#  'homes': 1,
#  'house demonstration': 1,
#  'housing': 3,
#  'housing first': 1,
#  'howard street': 1,
#  'hubway': 2,
#  'human games': 1,
#  'huron ave': 1,
#  'huron avenue sidewalks': 1,
#  'huron village': 1,
#  'ice/roller skating rink': 1,
#  'idaho': 1,
#  'improvement replacement plan': 1,
#  'improvements': 2,
#  'in cha properties': 1,
#  'income': 2,
#  'inman': 2,
#  'inman sq': 1,
#  'inman square': 3,
#  'inside': 1,
#  'install benches': 1,
#  'install timers': 1,
#  'interest': 1,
#  'interior': 1,
#  'internet': 2,
#  'intersection': 2,
#  'intersections': 2,
#  'inventory': 1,
#  'ipads': 2,
#  'ireport': 1,
#  'island': 2,
#  'items': 1,
#  'izzy': 1,
#  'jack': 1,
#  'jill brown rhone park': 1,
#  'joan lorentz park': 1,
#  'jobs': 1,
#  'justice': 1,
#  'kayak storage structure': 1,
#  'kendall sq': 1,
#  'kendall square': 1,
#  'kids': 3,
#  'king project': 1,
#  'lafayette': 1,
#  'lake': 1,
#  'land': 2,
#  'landing': 1,
#  'landscaping': 1,
#  'lanes': 1,
#  'laptops': 6,
#  'law': 1,
#  'lawn': 3,
#  'lawn on d': 1,
#  'learning disabilities': 1,
#  'lee street': 1,
#  'libraries': 7,
#  'library': 9,
#  'library garden': 1,
#  'license': 1,
#  'licenses': 1,
#  'light': 1,
#  'lighting': 12,
#  'lighting system': 1,
#  'lights': 6,
#  'line item': 1,
#  'line item support': 1,
#  'linear': 2,
#  'linear park': 3,
#  'lines': 1,
#  'little library': 1,
#  'lives': 1,
#  'location': 1,
#  'locations': 2,
#  'locker rooms': 1,
#  'locks': 1,
#  'longfellow park': 1,
#  'longfellow road': 1,
#  'lost & found': 1,
#  'lots': 1,
#  'lunch': 1,
#  'macbook air': 1,
#  'magazine st': 1,
#  'main': 1,
#  'main library': 5,
#  'main street': 1,
#  'mall': 1,
#  'many': 1,
#  'margaret fuller house': 1,
#  'maria baldwin school': 1,
#  'markers': 1,
#  'mass': 4,
#  'mass ave': 13,
#  'mass ave cambridge': 1,
#  'material': 1,
#  'mats': 1,
#  'mbta': 2,
#  'median': 1,
#  'medians': 1,
#  'meetings': 1,
#  'memorial drive': 3,
#  'meters': 1,
#  'mid-cambridge': 1,
#  'middle': 1,
#  'mindfulness events': 1,
#  'minds': 1,
#  'minuteman': 1,
#  'mit': 1,
#  'mitt mutt': 1,
#  'mobile city': 1,
#  'moms': 1,
#  'money': 2,
#  'monitors': 2,
#  'moore': 1,
#  'motion sensors': 1,
#  'movie center': 1,
#  'mt': 3,
#  'mural painters': 1,
#  'murals': 1,
#  'murder': 1,
#  'museum': 1,
#  'music studio': 1,
#  'music studio equipment': 1,
#  'neglected public spaces': 1,
#  'neighbor': 1,
#  'neighborhood - community participation': 1,
#  'neighborhood block parties': 1,
#  'neighborhood cookouts': 1,
#  'neighborhood meetings': 1,
#  'neighborhoods': 2,
#  'neighbors': 1,
#  'neighborways': 1,
#  'net': 1,
#  'neuroscience': 1,
#  'newcomers': 1,
#  'no cambridge t': 1,
#  "no man's land": 1,
#  'noise': 1,
#  'north cambridge': 8,
#  'north cambridge senior center': 1,
#  'number': 2,
#  "o'brien highway": 1,
#  'one': 1,
#  'one book': 1,
#  'one cambridge': 1,
#  'ones': 1,
#  'open access': 1,
#  'open air natural lap pool': 1,
#  'opp': 1,
#  'option': 1,
#  'otis': 1,
#  'out of town news': 1,
#  'outdoor fire pits': 1,
#  'outdoor gyms': 1,
#  'outlet': 1,
#  'outlets': 1,
#  'outreach': 1,
#  'outreach service': 1,
#  'outside': 1,
#  'painting roofs': 1,
#  'panels': 2,
#  'panhandling signs': 1,
#  'parcourse': 2,
#  'park': 7,
#  'parking': 8,
#  'parking app': 1,
#  'parking cars': 1,
#  'parking garage': 1,
#  'parking garages': 1,
#  'parking lot': 1,
#  'parking lots': 3,
#  'parking meters': 1,
#  'parkour': 1,
#  'parks': 21,
#  'part': 1,
#  'passenger': 1,
#  'passes': 1,
#  'passwords': 1,
#  'path': 8,
#  'patrons': 1,
#  'paul dudley': 1,
#  'pavement': 1,
#  'pay': 1,
#  'payson park': 1,
#  'peabody st': 1,
#  'peace garden': 1,
#  'peace garden memorial': 1,
#  'pedestrian connection': 1,
#  'pedestrian crossing': 1,
#  'pedestrian safety': 1,
#  'pedestrian walkway': 1,
#  'people': 5,
#  'performance space': 1,
#  'performances': 1,
#  'permit submissions': 1,
#  'pet therapy': 1,
#  'petting zoo': 1,
#  'pharmacy': 1,
#  'phone': 1,
#  'physical barrier for bike lane in tunnel': 1,
#  'picnic area': 1,
#  'picnic table': 1,
#  'pier': 1,
#  'pilot': 1,
#  'pilot program': 1,
#  'ping pong tables': 2,
#  'place recycling containers': 1,
#  'places': 1,
#  'plant bee': 1,
#  'plant trees': 1,
#  'planters': 1,
#  'playability': 1,
#  'playground': 5,
#  'playground equipment': 1,
#  'playgrounds': 2,
#  'playstations': 1,
#  'plots': 1,
#  'plymouth streets': 1,
#  'points': 1,
#  'police': 2,
#  'police communication': 1,
#  'police officers': 1,
#  'pool': 3,
#  'pools': 1,
#  'port - cherry st. lot garden & lopez park': 1,
#  'portapotty': 1,
#  'porter': 2,
#  'porter sq': 1,
#  'porter square': 2,
#  'porter square t station': 1,
#  'portion': 1,
#  'portions': 1,
#  'post office': 1,
#  'potholes': 1,
#  'power': 1,
#  'practice rooms': 1,
#  'program': 2,
#  'project': 1,
#  'projects': 2,
#  'properties': 1,
#  'property': 1,
#  'prospect': 1,
#  'prospect st': 1,
#  'prospect street': 1,
#  'public art': 1,
#  'public art studio': 1,
#  'public bathroom': 1,
#  'public bike stations': 1,
#  'public space': 1,
#  'pumping station': 1,
#  'purchase gum removal equipment': 1,
#  'putnam ave': 1,
#  'putnam cafe': 1,
#  'pv solar panels': 1,
#  'pvc': 1,
#  'quotes': 1,
#  'radios': 1,
#  'ranger station entrance': 1,
#  'rat': 1,
#  'rat bating': 1,
#  'raymond park': 2,
#  'raymond st park': 1,
#  'reclycling bins': 1,
#  'recreation': 1,
#  'recycling': 1,
#  'recycling baskets': 1,
#  'recycling bins': 1,
#  'recycling options': 1,
#  'recyling': 1,
#  'redesign': 1,
#  'refrigerator': 1,
#  'renovate lopez street park': 1,
#  'renovation': 1,
#  'repair path': 1,
#  'repave coolidge hill': 1,
#  'replacement': 2,
#  'reporting': 1,
#  'reservoir': 1,
#  'residential': 1,
#  'residents': 8,
#  'resource truck': 1,
#  'resources': 2,
#  'restoration': 1,
#  'retail space': 1,
#  'rethink lanes': 1,
#  'rindge ave': 4,
#  'river': 1,
#  'river street': 2,
#  'road': 2,
#  'road improvements': 1,
#  'road sculpture': 1,
#  'road test car': 1,
#  'roads': 2,
#  'roadways': 1,
#  'rock climbing wall': 1,
#  'rooftop garden': 2,
#  'rooftop gardens': 1,
#  'room': 1,
#  'rooms': 2,
#  'route': 1,
#  'rt. 2': 1,
#  'rules': 1,
#  'russell': 1,
#  'russell field': 5,
#  'russell youth center': 2,
#  'sacramento street community garden': 1,
#  'sacremento field': 1,
#  'safety': 2,
#  'scavenger hunt': 1,
#  'scholarship system': 1,
#  'school': 4,
#  'school lunches': 1,
#  'school programs': 1,
#  'schools': 9,
#  'seating': 2,
#  'seating area': 1,
#  'security cameras': 2,
#  'security systems': 1,
#  'senior': 1,
#  'senior center': 6,
#  'sennott park': 4,
#  'service': 1,
#  'services': 1,
#  'sewage': 1,
#  'shade': 2,
#  'shade tree': 1,
#  'shady hill school': 1,
#  'shelter': 1,
#  'shelters': 3,
#  'shopping': 1,
#  'shuttle': 1,
#  'side': 3,
#  'side blower': 1,
#  'sidewalk': 3,
#  'sidewalk accessibility': 1,
#  'sidewalks': 12,
#  'signage': 5,
#  'signs': 5,
#  'site': 1,
#  'skate park': 1,
#  'skating rink': 1,
#  'smell': 1,
#  'snap-match money': 1,
#  'sneakers': 1,
#  'snow': 3,
#  'snow melter': 1,
#  'snow removal': 1,
#  'snow removal tools': 1,
#  'snowblowers': 1,
#  'soccer families': 1,
#  'soccer nets': 1,
#  'solar charging stations': 1,
#  'solar panels': 3,
#  'solar power generation': 1,
#  'solidarity fridge': 1,
#  'somerville': 3,
#  'soofa benches': 1,
#  'sort': 1,
#  'space': 3,
#  'speakers': 1,
#  'species': 1,
#  'speed control crosswalk': 1,
#  'speed-bump': 1,
#  'sports complex': 1,
#  'spot': 1,
#  'st peters field': 1,
#  "st. peter's field": 1,
#  'staff': 1,
#  'stage': 1,
#  'stairs': 1,
#  'start cool roofs': 1,
#  'station': 2,
#  'station access road': 1,
#  'stations': 2,
#  'steps': 1,
#  'stockholm': 1,
#  'stop buttons': 1,
#  'stop signs': 1,
#  'storage area': 1,
#  'storm water management': 1,
#  'stormwater management': 1,
#  'street cleaning': 2,
#  'street level': 1,
#  'street light': 1,
#  'street lighting': 1,
#  'street lights': 2,
#  'street piano for public': 1,
#  'street signage': 1,
#  'street signs': 3,
#  'street snow blower': 1,
#  'street trees': 1,
#  'streets': 6,
#  'stretch': 1,
#  'strike posts': 1,
#  'strip': 1,
#  'strips': 1,
#  'student': 1,
#  'students': 3,
#  'study': 1,
#  'stuff': 1,
#  'stunt park': 1,
#  'subway stations': 1,
#  'suicide': 1,
#  'sullivan chamber': 1,
#  'summer shuttle': 1,
#  'supermarket bags': 1,
#  'support': 1,
#  'sweden': 1,
#  'swings': 4,
#  'systems': 1,
#  't': 2,
#  'tables': 1,
#  'tablets': 2,
#  'tax forms': 1,
#  'teachers': 1,
#  'technology': 1,
#  'teen center': 1,
#  'teens': 2,
#  'telephones': 1,
#  'tennis programs': 1,
#  'tennis wall': 1,
#  'tesla powerwalls': 1,
#  'the ride': 1,
#  'times': 1,
#  'tobin': 1,
#  'toddlers': 1,
#  'toilet': 2,
#  'toilets': 2,
#  'tools': 2,
#  'top': 2,
#  'tourist center': 1,
#  'tracking system': 1,
#  'traffic': 2,
#  'traffic calming': 2,
#  'traffic flow issues': 1,
#  'traffic garden': 1,
#  'traffic light': 1,
#  'traffic light coordination': 1,
#  'traffic light system': 1,
#  'traffic light timing': 1,
#  'traffic lights': 1,
#  'traffic signals': 1,
#  'traffic spots': 1,
#  'traffic study': 1,
#  'trailer': 1,
#  'train stations': 1,
#  'trampolines': 1,
#  'transit screen': 2,
#  'transit signal priority': 1,
#  'trash barrels': 1,
#  'trash bins': 1,
#  'trash cans': 3,
#  'tree': 1,
#  'trees': 12,
#  'trial': 1,
#  'trial deployments': 1,
#  'triangle': 1,
#  'trike': 1,
#  'trips': 1,
#  'trowbridge st': 1,
#  'truck': 2,
#  'tubes': 1,
#  'tudor st': 1,
#  'turn': 2,
#  'turnaround': 1,
#  'tutors': 1,
#  'union square': 1,
#  'units': 1,
#  'universal design playground': 1,
#  'up our parks': 1,
#  'upland rd': 1,
#  'upper school': 1,
#  'use': 3,
#  'user friendly': 1,
#  'valente library': 3,
#  'valente library branch': 1,
#  'vassal lane upper school': 1,
#  'vassar': 1,
#  'vehicles': 1,
#  'vellucci park': 1,
#  'vending machines': 2,
#  'verizon fios': 1,
#  'version': 1,
#  'veterans': 1,
#  'video games': 1,
#  'visibility placement': 1,
#  'volleyball court': 1,
#  'w': 1,
#  'walden street': 2,
#  'walk': 1,
#  'walk lights': 2,
#  'walk path': 1,
#  'walk-bike path': 1,
#  'walk/bike path': 1,
#  'walkers': 1,
#  'walking path': 1,
#  'walkways': 1,
#  'war memorial': 2,
#  'waste': 1,
#  'wastebaskets': 1,
#  'water': 1,
#  'water bottle': 1,
#  'water bottles': 1,
#  'water feature': 1,
#  'water features': 1,
#  'water fountain': 1,
#  'water fountains': 3,
#  'waterhouse square': 1,
#  'watering': 1,
#  'watertown': 1,
#  'way': 2,
#  'way-finding': 1,
#  'wayfinding sign': 1,
#  'website': 1,
#  'welcome': 1,
#  'welcome center': 1,
#  'wellington-harrington community garden': 1,
#  'west st.': 1,
#  'wheelchair users': 1,
#  'white street': 1,
#  'wi-fi': 13,
#  'windmill': 1,
#  'windows': 1,
#  'windsor st. side': 1,
#  'winter': 1,
#  'winter oasis': 1,
#  'wires': 1,
#  'work': 1,
#  'xboxes': 1,
#  'yellow bumpers': 1,
#  'youth': 4,
#  'youth centers': 6}

# %%
total_freq_count_by_cycle['PB3(June-December 2016)']
# Out:
# {'': 3,
#  '1050 mass ave': 1,
#  '18 pound american cannon': 1,
#  '3rd street': 1,
#  'a second entrance set of covered benches': 1,
#  'aberdeen': 1,
#  'access': 1,
#  'adirondack': 2,
#  'adults': 2,
#  'african-american trail': 1,
#  'alberico play ground': 1,
#  'alewife': 1,
#  'alewife linear parkway': 1,
#  'alewife t': 1,
#  'all': 1,
#  'amigos public school': 1,
#  'amount': 1,
#  'amusement park': 1,
#  'announcement reboot': 1,
#  'app': 2,
#  'area': 2,
#  'area 4': 2,
#  'area four': 1,
#  'area improvements': 1,
#  'areas': 1,
#  'arrival': 1,
#  'art': 2,
#  'art centers': 1,
#  'art on fire': 1,
#  'art supplies': 3,
#  'asperger': 1,
#  'babies': 1,
#  'baby boxes': 1,
#  'baby university program': 1,
#  'bags': 2,
#  'balls': 1,
#  'baseball backstop': 1,
#  'baseball fields': 1,
#  'basketball court': 2,
#  'basketball hoop': 1,
#  'bat boxes': 1,
#  'bathing beach idea': 1,
#  'bathing suits': 1,
#  'bathroom': 1,
#  'beacon @ aaas': 1,
#  'beautification': 1,
#  'beech tree': 1,
#  'beech-elm': 1,
#  'bench': 1,
#  'benches': 4,
#  'benefits': 1,
#  'berkshire': 1,
#  'bernard': 1,
#  'bicycle': 2,
#  'bicycle desks': 1,
#  'bicycle lanes': 1,
#  'bicycle parking': 2,
#  'bicycle parking subsidies': 1,
#  'bicycle rack': 1,
#  'bicycle safety education': 1,
#  'bicycle signs': 1,
#  'bicycles': 1,
#  'bicycles stickers': 1,
#  'bicycling': 1,
#  'bidet': 1,
#  'big belly': 1,
#  'bike': 3,
#  'bike box': 1,
#  'bike crosswalk': 1,
#  'bike fatalities': 1,
#  'bike helmets': 1,
#  'bike lane': 7,
#  'bike lanes': 9,
#  'bike parking': 3,
#  'bike path': 2,
#  'bike paths': 1,
#  'bike rack': 1,
#  'bike racks': 1,
#  'bike safety': 1,
#  'bike sidewalk': 1,
#  'bike signal': 2,
#  'bike signals': 1,
#  'bike signs': 1,
#  'bike theft': 1,
#  'bike trail': 1,
#  'bike washing station': 1,
#  'biker lane': 1,
#  'bikes': 4,
#  'biking': 3,
#  'biking shelter': 1,
#  'binney street': 1,
#  'blackstone street': 1,
#  'block': 1,
#  'board': 1,
#  'body cameras': 1,
#  'books': 1,
#  'bottle filler': 3,
#  'box': 2,
#  'brattle': 1,
#  'bridge': 1,
#  'brigade': 1,
#  'bristol st b/': 1,
#  'broadway': 6,
#  'brunswick': 1,
#  'bu bridge intersection': 1,
#  'buckets': 1,
#  'bug spray': 1,
#  'building': 1,
#  'building community': 1,
#  'buildings': 3,
#  'bump': 1,
#  'bumper stickers': 1,
#  'burger king': 1,
#  'bus': 2,
#  'bus alert screens': 1,
#  'bus arrival data': 1,
#  'bus displays': 1,
#  'bus lane': 1,
#  'bus lanes': 1,
#  'bus shelter': 3,
#  'bus shelters': 2,
#  'bus stop': 2,
#  'bus stop pole information': 1,
#  'bus stops': 4,
#  'bus-stops': 1,
#  'buses': 2,
#  'business districts': 1,
#  'business workspaces': 1,
#  'businesses': 1,
#  'button': 1,
#  'bypass': 1,
#  'cambridge': 33,
#  'cambridge cares': 1,
#  'cambridge clean': 1,
#  'cambridge common': 3,
#  'cambridge concert stage': 1,
#  'cambridge elementary school': 1,
#  'cambridge graffiti trail': 1,
#  'cambridge kids': 1,
#  'cambridge plaza of stars': 1,
#  'cambridge public elementary school': 1,
#  'cambridge public library': 2,
#  'cambridge public makerspace': 1,
#  'cambridge school volunteers': 1,
#  'cambridge seeen shelter environment empowerment & education network': 1,
#  'cambridge st': 2,
#  'cambridge street composting': 1,
#  'cambridge youth programs shuttles': 1,
#  'cambridgepark drive relief': 1,
#  'cambridgeport dog park': 1,
#  'cambridgeport youth center': 1,
#  'cambridgeside galleria': 1,
#  'cameras': 1,
#  'canopy': 1,
#  'car': 1,
#  'cardinal': 1,
#  'cardinal medeiros': 1,
#  'cars': 2,
#  'cell phones': 1,
#  'center': 1,
#  'central': 1,
#  'central sq': 3,
#  'central square': 10,
#  'central square library': 1,
#  'chairs': 3,
#  'charging stations': 2,
#  'charles': 3,
#  'charles river bagh': 1,
#  'charles river conservancy': 1,
#  'chess': 1,
#  'children': 1,
#  'cigarette disposal receptacles': 1,
#  'city': 6,
#  'city flag': 1,
#  'city hall': 1,
#  'city of cambridge': 1,
#  'city of cambridge sound pollution study': 1,
#  'city trash can': 1,
#  'city trees': 1,
#  'cleaner streets': 1,
#  'clement g. morgan park': 1,
#  'color printer': 1,
#  'columbia': 2,
#  'comeau field': 1,
#  'commemorations': 1,
#  'community': 1,
#  'community garden': 4,
#  'community ideas exchange and social dance': 1,
#  'community learning center': 1,
#  'community organic garden': 1,
#  'community power tool rental': 1,
#  'community school registration system': 1,
#  'commuting spot': 1,
#  'composting program': 1,
#  'composting receptacles': 1,
#  'computer': 1,
#  'computer programming course': 1,
#  'computers': 7,
#  'concord ave': 1,
#  'connections': 1,
#  'construction': 1,
#  'construction alert website': 1,
#  'cooling station': 1,
#  'copenhagen bike lanes': 1,
#  'copiers': 1,
#  'corner': 1,
#  'counterflow': 1,
#  'cps': 1,
#  'cps schools': 1,
#  'creation': 1,
#  'cricket pitch': 1,
#  'crls': 3,
#  'crls freight farm': 1,
#  'cross walk': 1,
#  'crossing opportunities': 1,
#  'crosswalk': 4,
#  'crosswalk river street & mass': 1,
#  'crosswalks': 2,
#  'cycle': 1,
#  'cycle tracks': 1,
#  'cyclists': 3,
#  'dance studio': 1,
#  'danehy': 2,
#  'danehy dog park': 1,
#  'danehy park': 2,
#  'danehy park amphitheatre': 1,
#  'data projector': 1,
#  'daycare center': 1,
#  'daycares': 1,
#  'de-militarization': 1,
#  'deadly inman square': 1,
#  'design competition': 1,
#  'desks': 1,
#  'desktop': 1,
#  'diaper gap': 1,
#  'direction': 2,
#  'disposable diaper waste': 1,
#  'diversity': 1,
#  'dog bag dispensers': 1,
#  'dog bowl': 1,
#  'dog park': 3,
#  'dog poop bags': 1,
#  'dog washing station': 1,
#  'donation boxes': 1,
#  'donation stations': 1,
#  'door': 1,
#  'dpw yard': 1,
#  'drinking fountains': 2,
#  'drivers': 1,
#  'dudley street park': 1,
#  'e-books': 1,
#  'e.g.': 1,
#  'east cambridge': 2,
#  'east cambridge dog park': 1,
#  'east cambridge planning team': 1,
#  'elementary schools': 1,
#  'elevator kiosk': 1,
#  'ellery street': 1,
#  'end homelessness': 1,
#  'english': 1,
#  'entrance': 1,
#  'entry': 1,
#  'environmental quality monitoring stations': 1,
#  'equipment': 3,
#  'esl': 1,
#  'ev': 1,
#  'events': 1,
#  'exercise equipment': 3,
#  'exit routes': 1,
#  'experience': 1,
#  'facelift': 1,
#  'families': 1,
#  'fiber optic network': 1,
#  'fibre optic network': 1,
#  'fios': 1,
#  'fire hydrant visibility': 1,
#  'fire hydrants': 1,
#  'fitness programs': 1,
#  'food': 1,
#  'food banks': 1,
#  'footbridges': 1,
#  'fort washington': 1,
#  'franklin st': 1,
#  'fresh pond': 7,
#  'fresh pond bikeway': 1,
#  'fresh pond north library': 1,
#  'front': 3,
#  'fruit gleaning program': 1,
#  'function hall': 1,
#  'funds': 1,
#  'furniture': 2,
#  'galileo way': 1,
#  'garage': 1,
#  'gardner street': 1,
#  'general use small parks': 1,
#  'gift of the wind': 1,
#  'gilmore bridge': 1,
#  'glenwood street': 1,
#  'gore st.': 2,
#  'gps': 2,
#  'gravel nesting pads': 1,
#  'green street': 1,
#  'greenhouses': 1,
#  'grown ups': 1,
#  'gym': 1,
#  'gym space': 1,
#  'h2o': 1,
#  'haggerty': 1,
#  'hampshire': 1,
#  'hampshire street improvements': 1,
#  'handicap accessibility': 1,
#  'handles': 1,
#  'harvard': 3,
#  'harvard square': 5,
#  'harvard streets': 1,
#  'hastings square': 1,
#  'havard square central area': 1,
#  'healing wing': 1,
#  'heat': 1,
#  'helmet': 1,
#  'help': 1,
#  'hfa': 1,
#  'highway': 1,
#  'history walls': 1,
#  'homeless': 9,
#  'homeless shelter': 4,
#  'homeless shelters': 1,
#  'homelessness': 1,
#  'homelessness task force': 1,
#  'hoop': 2,
#  'hoops': 2,
#  'hostel': 1,
#  'hot water project': 1,
#  'houses': 2,
#  'housing': 3,
#  'hubway': 1,
#  'human right': 1,
#  'hurley street park': 1,
#  'ice cream': 1,
#  'icon': 1,
#  'idea': 1,
#  'improvement initiative': 1,
#  'income': 1,
#  'incubator kitchen': 1,
#  'inman square': 8,
#  'inman st': 1,
#  'inner circle': 1,
#  'inspection': 1,
#  'internet': 3,
#  'internet exchange parking spaces': 1,
#  'internet purchase exchange location': 1,
#  'internet reliability': 1,
#  'interns': 1,
#  'intersection': 9,
#  'intersection of mass ave': 1,
#  'intersections': 2,
#  'irish': 1,
#  'irving': 1,
#  'izzy': 1,
#  'jefferson park': 4,
#  "jerry's pit": 1,
#  "jerry's pond": 1,
#  'joan lorentz park': 1,
#  'jungle gym': 1,
#  'kendall': 1,
#  'kids': 2,
#  'kinetic energy tiles': 1,
#  'kingsley park': 1,
#  'kirkland streets': 1,
#  'landscaping': 1,
#  'laundry facilities': 1,
#  'lc': 1,
#  'learning center': 1,
#  'learning production centers': 1,
#  'led street lights': 1,
#  'lesley': 1,
#  'library': 6,
#  'library lending': 1,
#  'light': 1,
#  'light charles sumner': 1,
#  'light to latin school gate': 1,
#  'lighting': 1,
#  'lights': 3,
#  'lincoln': 1,
#  'linear path': 1,
#  'lines': 1,
#  'links homelessness with poverty': 1,
#  'literacy': 1,
#  'literacy center': 1,
#  'little free library': 3,
#  'little free pantry initiative': 1,
#  'little league scoreboards': 1,
#  'livability revamp': 1,
#  'lot': 2,
#  'lowell park': 2,
#  'lunch line': 1,
#  'lynch family': 1,
#  'magazine beach': 2,
#  'main library': 1,
#  'main public library': 1,
#  'main street': 1,
#  'maine': 1,
#  'maintenance issues': 1,
#  'markers': 1,
#  'mass': 1,
#  'mass ave': 7,
#  'mass ave cycle track': 1,
#  'massachusetts': 1,
#  'massachusetts avenue center divider': 1,
#  'materials': 1,
#  'mats': 1,
#  'mbta': 1,
#  'measures': 1,
#  'medeiros st': 1,
#  'memorial park': 1,
#  'middle school': 1,
#  'middle school students': 1,
#  'mini-libraries': 1,
#  'minuteman': 1,
#  'mission': 1,
#  'mit': 3,
#  'mobile app payment': 1,
#  'mobile hygiene': 1,
#  'mobile pop-up gallery space for artists': 1,
#  'monitoring': 1,
#  'monkey bars': 1,
#  'monument lighting': 1,
#  'moore youth': 1,
#  'moore youth center': 2,
#  'motion sensors': 1,
#  'mural': 1,
#  'music venues': 1,
#  'name': 1,
#  'names': 1,
#  'need': 2,
#  'neighborhood': 2,
#  'neighborhood safety': 1,
#  'neighborhoods': 2,
#  'new bus shelter': 1,
#  'new pilot curiculuum': 1,
#  'nighthawks': 1,
#  'noise awareness': 1,
#  'noiseless': 1,
#  'north cambridge': 4,
#  'north point park': 2,
#  'nursing area': 1,
#  "o'brien/land blvd": 1,
#  'official dog park': 1,
#  'one': 1,
#  'one main street': 1,
#  'opening': 1,
#  'opening magazine beach': 1,
#  'opportunities': 1,
#  'opportunity': 1,
#  'outdoor fitness': 1,
#  'outdoor rollerskating rink': 1,
#  'oxford street': 2,
#  'pals park': 1,
#  'panels': 1,
#  'paper shredding': 1,
#  'paris': 1,
#  'park': 8,
#  'parking': 1,
#  'parking lot': 1,
#  'parking meters': 3,
#  'parking spaces': 1,
#  'parklet': 2,
#  'parklet boulevard': 1,
#  'parklets': 2,
#  'parks': 5,
#  'parrow park': 1,
#  'part': 1,
#  'path': 1,
#  'pathway': 2,
#  'payment': 1,
#  'peabody school playground': 1,
#  'pedestrian': 3,
#  'pedestrian crossing': 1,
#  'pedestrian crossings': 1,
#  'pedestrian paths': 1,
#  'pedestrian safety': 1,
#  'pedestrian visibility': 1,
#  'pedistrians': 1,
#  'people': 2,
#  'performance pavillion': 1,
#  'perimeter': 1,
#  'perimeter shrubs': 1,
#  'phase': 1,
#  'phone': 1,
#  'picnic table': 1,
#  'picnic tables': 2,
#  'pilot study': 1,
#  'places': 1,
#  'plaque': 1,
#  'playground': 8,
#  'playground equipment': 1,
#  'playgrounds': 2,
#  'plumbing': 1,
#  'police': 1,
#  'police hq': 1,
#  'police man': 1,
#  'police officers': 2,
#  'police vehicles': 1,
#  'pollinator meadow': 1,
#  'pool': 2,
#  'porkchop': 1,
#  'porter sq': 1,
#  'porter sq t': 1,
#  'porter square': 4,
#  'portland street': 1,
#  'posters': 1,
#  'posts': 1,
#  'potholes': 1,
#  'prescott st': 1,
#  'preservation': 1,
#  'printers': 2,
#  'production studios': 1,
#  'project': 1,
#  'prospect': 1,
#  'prospect street': 2,
#  'prospect/river': 1,
#  'public': 1,
#  'public art': 1,
#  'public art space': 1,
#  'public art wall': 1,
#  'public docks': 1,
#  'public information kiosk': 1,
#  'public postering': 1,
#  'public school classes': 1,
#  'public space': 1,
#  'punjabi dhaba': 1,
#  'putnam avenue': 1,
#  'quincy': 1,
#  'rainbow crosswalks': 1,
#  'raspberry pi stations': 1,
#  'rat infestation': 1,
#  'rat problem': 1,
#  'rats': 1,
#  'recording': 1,
#  'recreation': 1,
#  'recycling': 1,
#  'recycling bins': 3,
#  'recycling centers': 1,
#  'recycling container': 1,
#  'red line': 1,
#  'refugees': 1,
#  'registration': 1,
#  'reminders': 1,
#  'removal': 1,
#  'renting': 1,
#  'repair nets': 1,
#  'replacement chairs': 1,
#  'residents': 2,
#  'resources': 1,
#  'restoration': 1,
#  'restroom facilities': 1,
#  'restrooms': 1,
#  'revitalization': 1,
#  'rfids': 1,
#  'rindge': 1,
#  'rindge ave.': 1,
#  'rings': 1,
#  'rink': 1,
#  'river': 2,
#  'river street': 1,
#  'river street courts': 1,
#  'road': 1,
#  'roads': 1,
#  'rodent control': 1,
#  'roof': 1,
#  'roofs': 2,
#  'rooftop community gardens': 1,
#  'rooftop gardens': 1,
#  'ropes': 1,
#  'round': 1,
#  'route 2': 1,
#  'runoff': 1,
#  'russell field': 2,
#  'russell field pool house': 1,
#  'sacramento field': 1,
#  'safe': 1,
#  'safer crosswalks along hampshire st': 1,
#  'safer cycling': 1,
#  'safety': 8,
#  'sam langford': 1,
#  'samosa nirvana': 1,
#  'sand volleyball court': 1,
#  'school': 3,
#  'school food': 1,
#  'schools': 3,
#  'sciarappa st.': 1,
#  'score boards': 1,
#  'sculpture': 1,
#  'seating': 2,
#  'security': 1,
#  'senior center': 1,
#  'senior center bus shelter': 1,
#  'senior centers': 1,
#  'senior housing': 1,
#  'seniors': 2,
#  'sennott park': 1,
#  'service': 1,
#  'sharing': 1,
#  'shelter': 1,
#  'shepard st. bicycle boulevard': 1,
#  'sherman street': 2,
#  'showers': 1,
#  'side streets': 1,
#  'sides': 1,
#  'sidewalk': 3,
#  'sidewalk accessibility': 1,
#  'sidewalk bump': 1,
#  'sidewalk signs': 1,
#  'sidewalk use': 1,
#  'sidewalkers': 1,
#  'sidewalks': 4,
#  'sidewalks stroller': 1,
#  'signage wire': 1,
#  'signal': 1,
#  'signal heads': 1,
#  'signals': 2,
#  'signs': 4,
#  'sites': 1,
#  'skate park': 2,
#  'small floating kayak launch': 1,
#  'smoking spaces': 1,
#  'snow melt systems': 1,
#  'soccer field': 1,
#  'soccer post': 1,
#  'solar chargers': 1,
#  'solar panel basketball court': 1,
#  'solar panels': 1,
#  'soldier': 1,
#  'solution': 1,
#  'someone': 1,
#  'something': 1,
#  'soup kitchen': 1,
#  'space': 3,
#  'sparks st': 1,
#  'speakers': 1,
#  'speed bump': 1,
#  'speed limit signs': 1,
#  'speed tables': 1,
#  'spot': 1,
#  'spots': 1,
#  'spray deck area': 1,
#  'spray paint': 1,
#  'square': 2,
#  'squares': 1,
#  'squirrel': 1,
#  'squirrel brand park': 1,
#  "st. peter's park parking lot": 1,
#  'staff room': 1,
#  'stage': 2,
#  'stand desks': 1,
#  'station': 2,
#  'station improvements': 1,
#  'statue': 1,
#  'statue in macarthur park': 1,
#  'stipends': 1,
#  'stop': 1,
#  'stop lights': 1,
#  'storage space': 1,
#  'stories': 1,
#  'storm safety': 1,
#  'street': 4,
#  'street cleaning': 1,
#  'street cleaning parking reminder': 1,
#  'street cleaning vehicles': 1,
#  'street lamps': 1,
#  'street repair': 1,
#  'street trees': 2,
#  'streets': 1,
#  'students': 2,
#  'studios': 1,
#  'suggestions': 1,
#  'sunscreen stations': 1,
#  'suppers': 1,
#  'supplies': 1,
#  'support': 1,
#  'surplus restaurant food': 1,
#  'surroundings': 1,
#  'swimming pool': 1,
#  'swing': 1,
#  'swing set': 1,
#  't exit': 1,
#  'tables': 1,
#  'tablets': 1,
#  'technology': 1,
#  'telescope equipment': 1,
#  'temple': 1,
#  'tennis courts': 1,
#  'the old burial ground': 1,
#  'the port': 1,
#  'throughtout': 1,
#  'tmp': 1,
#  'toilet': 3,
#  'toilets': 3,
#  'tool library': 1,
#  'tor exit node': 1,
#  'town': 1,
#  'track': 1,
#  'trackless municipal snow blowers': 1,
#  'traffic areas': 1,
#  'traffic control': 1,
#  'traffic laws': 1,
#  'traffic light': 1,
#  'traffic light intervals': 1,
#  'traffic lights': 2,
#  'traffic patterns': 1,
#  'traffic safety garden': 1,
#  'train': 1,
#  'train station': 1,
#  'train stations': 1,
#  'tranport hub/triangle': 1,
#  'transit information screens': 1,
#  'transit ridership': 1,
#  'transit screens': 1,
#  'transition': 1,
#  'transparency': 1,
#  'transportation van': 1,
#  'trash': 2,
#  'trash cans': 3,
#  'trash compactors': 1,
#  'trashcans': 1,
#  'tree injury': 1,
#  'treehouses': 1,
#  'trees': 5,
#  'truck showers': 1,
#  'universal design playground elements': 1,
#  'unsafe inman square': 1,
#  'updates': 1,
#  'upper school': 1,
#  'urban ecology center': 1,
#  'van': 1,
#  'vassar': 1,
#  'vassar street': 1,
#  'vehicle charging stations': 1,
#  'vellucci community plaza': 1,
#  'volleyball court': 1,
#  'voter registration': 1,
#  'wading pool': 1,
#  'walk': 1,
#  'walkway': 1,
#  'wall': 2,
#  'wall art': 1,
#  'ware': 1,
#  'water bottle': 2,
#  'water fountain': 8,
#  'water fountains': 1,
#  'water park': 1,
#  'water park facilities': 1,
#  'water spigot': 1,
#  'water taste': 1,
#  'water taxi': 1,
#  'watertown greenway': 1,
#  'watertown-cambridge greenway': 1,
#  'watson street': 1,
#  'way': 2,
#  'weather canopy': 1,
#  'website': 1,
#  'webster': 2,
#  'western': 1,
#  'wet': 1,
#  'wheelchair': 1,
#  'wheelchair curb cuts': 1,
#  'wi fi': 2,
#  'wi-fi': 1,
#  'wifi': 6,
#  'wifi hotspots': 1,
#  'wilder lee street park': 1,
#  'windsor street': 1,
#  'workout station': 1,
#  'youth center makeovers': 1,
#  'youth centers': 1,
#  'youth programs': 1,
#  'zip vans': 1,
#  'zipcars': 1}

# %%
total_freq_count_by_cycle['PB4(June-December 2017)']
# Out:
# {'': 1,
#  ' playground and bandshell': 1,
#  '46 pleasant street': 1,
#  '@ bus stops': 1,
#  '@ cameron ave': 1,
#  'abilities': 1,
#  'ac': 1,
#  'access': 4,
#  'accidents': 1,
#  'adult playground': 1,
#  'advertising': 1,
#  'age': 1,
#  'aggressive driving reporting': 1,
#  'air conditioning': 1,
#  'albany st': 1,
#  'alewife': 4,
#  'alewife brook': 1,
#  'alewife brook parkway': 2,
#  'alewife community garden': 1,
#  'alewife exits': 1,
#  'all': 3,
#  'all directions': 1,
#  'all public housing': 1,
#  'amharic books': 1,
#  'ami': 1,
#  'archery': 1,
#  'area': 5,
#  'area 4 courts': 1,
#  'area youth': 1,
#  'areas': 1,
#  'arlington': 2,
#  'arlington line': 1,
#  'art installation': 1,
#  'artwork': 1,
#  'asphalt': 3,
#  'asthetics': 1,
#  'athletic equipment': 1,
#  'atrium': 1,
#  'auburn': 1,
#  'auburn street': 1,
#  'autistic': 1,
#  'availability': 1,
#  'ave': 1,
#  'awareness': 1,
#  'band shell': 1,
#  'bankshot playcourts sports facilities': 1,
#  'banner holders': 1,
#  'bark park': 1,
#  'barrier': 1,
#  'barron park': 1,
#  'basketball court': 2,
#  'basketball courts': 2,
#  'bathroom': 1,
#  'batting cages': 1,
#  'beach': 1,
#  'beautify park': 1,
#  'beech': 1,
#  'bees': 2,
#  'bench': 2,
#  'benches': 3,
#  'better equipment': 1,
#  'bicycle': 2,
#  'bicycle bells': 1,
#  'bicycle desks': 2,
#  'bicycle parking': 1,
#  'bicycle racks': 1,
#  'bicycle sharing': 1,
#  'bicycle wash': 1,
#  'bigbelly': 1,
#  'bike': 1,
#  'bike bridge': 2,
#  'bike counters': 1,
#  'bike lane': 15,
#  'bike lane pinch point': 1,
#  'bike lanes': 20,
#  'bike liners': 1,
#  'bike offenders': 1,
#  'bike parking': 1,
#  'bike path': 8,
#  'bike path solution': 1,
#  'bike paths': 2,
#  'bike racks': 4,
#  'bike rental': 1,
#  'bike repair station': 1,
#  'bike routes': 1,
#  'bike safety': 1,
#  'bikeracks': 1,
#  'bikers': 1,
#  'bikes': 5,
#  'biking': 1,
#  'binney': 1,
#  'bins': 1,
#  'biochar': 1,
#  'bioswales': 1,
#  'birdbath': 1,
#  'birthday': 1,
#  'black american historical sites': 1,
#  'blighting': 1,
#  'block': 2,
#  'blood pressure monitoring stations': 1,
#  'blue sky': 1,
#  'board games': 1,
#  'book exchange box': 1,
#  'books': 3,
#  'border': 1,
#  'borrowing': 1,
#  'bottle': 1,
#  'bottle refill': 1,
#  'branch': 1,
#  'brattle st.': 1,
#  'brattle st. & huron ave': 1,
#  'brattle street': 1,
#  'brick sidewalk sections': 1,
#  'bridge': 3,
#  'broadband utility': 1,
#  'broadway': 5,
#  'broadway st': 1,
#  'bu': 2,
#  'bubbler': 1,
#  'budget process': 1,
#  'building blocks': 1,
#  'buildings': 1,
#  'buildins': 1,
#  'bump': 1,
#  'bump-outs': 1,
#  'bury': 1,
#  'bus': 4,
#  'bus lanes': 2,
#  'bus routes': 1,
#  'bus shelter': 2,
#  'bus stop': 2,
#  'bus stop shelter': 1,
#  'bus stops': 1,
#  'buses': 1,
#  'businesses': 2,
#  'butterflies': 1,
#  'cambridge': 25,
#  'cambridge basketball courts': 1,
#  'cambridge common': 3,
#  'cambridge commons cafe': 1,
#  'cambridge girls softball league': 1,
#  'cambridge girls softball league field': 1,
#  'cambridge library lawn': 1,
#  'cambridge parks': 1,
#  'cambridge public school': 1,
#  'cambridge st': 1,
#  'cambucks': 1,
#  'cameras': 2,
#  'car': 1,
#  'car charging options': 1,
#  'car charging stations': 1,
#  'car emissions': 1,
#  'car safety': 1,
#  'car traffic': 1,
#  'carbon monoxide detectors': 1,
#  'cardinal medeiros': 1,
#  'cardinal medeiros ave': 1,
#  'career resources': 2,
#  'cars': 2,
#  'center': 1,
#  'central': 1,
#  'central sq': 1,
#  'central square': 6,
#  'central square branch library': 1,
#  'charging benches': 1,
#  'charging booths': 1,
#  'charging stations': 4,
#  'charles hotel': 1,
#  'charles river': 6,
#  'charles river bike': 1,
#  'charles river pedestrian': 1,
#  'chestnut': 1,
#  'chicken co-ops': 1,
#  'chicken coops': 1,
#  'child seats': 1,
#  'christmas lights': 1,
#  'christmas trees': 1,
#  'cigarette butt disposal': 1,
#  'circle': 1,
#  'citizens': 1,
#  'city': 6,
#  'city hall': 1,
#  'city parks': 1,
#  'city playgrounds': 1,
#  'city sports fields': 1,
#  'city wide composting': 1,
#  'city workers': 1,
#  'city yard': 1,
#  'citywide': 1,
#  'classrooms': 1,
#  'clc': 2,
#  'climate impact signs': 1,
#  'coast': 1,
#  'coffee & artist square': 2,
#  'comcast': 1,
#  'comeau field': 1,
#  'commercial corridors': 1,
#  'common': 1,
#  'commonwealth': 1,
#  'community bee hives': 1,
#  'community compost bins': 1,
#  'community garden': 2,
#  'community gardens': 5,
#  'community greenhouse': 1,
#  'community learning center': 1,
#  'commuter rail tracks': 1,
#  'compost': 1,
#  'compost barrels': 1,
#  'compost bins': 1,
#  'compost drop': 1,
#  'compost pickup': 1,
#  'composting': 1,
#  'composting toilet': 1,
#  'composting toliet': 1,
#  'concerts': 1,
#  'concord ave': 1,
#  'concrete': 1,
#  'connection': 1,
#  'connections': 1,
#  'construction': 1,
#  'contemplative path': 1,
#  'contra': 1,
#  'contra flow bike lane': 1,
#  'copper beeches': 1,
#  'cost': 1,
#  'courts': 2,
#  'cps': 1,
#  'credit card': 1,
#  'cremation scattering garden': 1,
#  'crls': 6,
#  'crls rooftop solar': 1,
#  'cross traffic': 1,
#  'cross walk': 1,
#  'crossing': 1,
#  'crossing guard': 1,
#  'crossroads': 1,
#  'crosswalk': 10,
#  'crosswalk signs': 1,
#  'crosswalks': 4,
#  'ct2 bus route': 1,
#  'curb cut': 1,
#  'curbs': 1,
#  'curbside composting pick-up': 1,
#  'currency': 1,
#  'curvilinear': 1,
#  'cvs': 1,
#  'cycle track': 2,
#  'cycle tracks': 3,
#  'cycling infrastructure': 1,
#  'cyclist': 1,
#  'cyclist safety project': 1,
#  'cyp': 1,
#  'danahy park': 1,
#  'danehy': 3,
#  'danehy 3': 1,
#  'danehy dog park': 2,
#  'danehy field': 1,
#  'danehy park': 9,
#  'danehy park water fountains': 1,
#  'data book': 1,
#  'daycare scholarships': 1,
#  'de-paving party': 1,
#  'design playground': 1,
#  'digester': 1,
#  'display': 1,
#  'divide': 1,
#  'dog': 1,
#  'dog drinking fountain': 1,
#  'dog park': 3,
#  'dog parks': 1,
#  'dog poop bag stations': 1,
#  'doggie dream park': 1,
#  'dogs': 3,
#  'dpw': 1,
#  'drinking': 1,
#  'drinking fountain sculptures': 1,
#  'drive': 1,
#  'drop off': 1,
#  'drop off zones': 1,
#  'dudley white': 1,
#  'dyson airblade': 1,
#  'east cambridge': 1,
#  'eco safe digester': 1,
#  'electric cars': 1,
#  'ellery - broadway': 1,
#  'elm intersection': 1,
#  'emergency bicycle maintenance stand': 1,
#  'emissions': 1,
#  'employees': 1,
#  'energy efficiency': 1,
#  'english': 1,
#  'entrance': 1,
#  'entry points': 1,
#  'eps': 1,
#  'ev': 1,
#  'events': 1,
#  'everyone': 3,
#  'everywhere': 1,
#  'fall': 1,
#  'fawcett street': 2,
#  'feasibility study': 2,
#  'fence': 3,
#  'field': 2,
#  'field playground': 1,
#  'field st': 1,
#  'fill stations': 1,
#  'filling station': 1,
#  'fix alewife': 1,
#  'fix ceiling': 1,
#  'fix inman square': 1,
#  'flags': 2,
#  'flex posts': 1,
#  'floating dock': 1,
#  'flower -garden': 1,
#  'flower garden': 1,
#  'food': 1,
#  'fort washington': 1,
#  'forum at mt': 1,
#  'foundation': 1,
#  'franklin st': 1,
#  'franklin street': 1,
#  'fresh pond': 6,
#  'fresh pond mall parking lot': 1,
#  'fresh pond mall pedestrian access': 1,
#  'fresh pond mall step ladder': 1,
#  'fresh pond parkway': 1,
#  'fresh pond reservation': 1,
#  'fresh pond tennis courts': 1,
#  'fresh red paint job': 1,
#  'front': 5,
#  'fund': 1,
#  'funding': 1,
#  'furniture bank': 1,
#  'garbage': 1,
#  'garden': 1,
#  'garden st': 1,
#  'garden street': 1,
#  'gately youth center': 3,
#  'gates': 1,
#  'gateway': 1,
#  'gathering/ lunch spot': 1,
#  "gentleman's repair": 1,
#  'gift of the wind': 1,
#  'glacken field': 2,
#  'gold star mothers park': 1,
#  'gore st field': 1,
#  'got talent': 1,
#  'graffiti': 1,
#  'granny cart': 1,
#  'green bridge': 1,
#  'green connector': 1,
#  'green house sanctuary for bees': 1,
#  'green infrastructure city': 1,
#  'green patio - piazza in central square': 2,
#  'green space': 1,
#  'green street bus lane': 1,
#  'green walls': 1,
#  'gyorgy kepes': 1,
#  'h2o': 1,
#  'half': 1,
#  'hand dryers': 1,
#  'hand washing stations': 1,
#  'hands': 1,
#  'harvard': 3,
#  'harvard sq': 3,
#  'harvard square': 8,
#  'harvey & cedar': 1,
#  'hazardous waste collection': 1,
#  'heat lamps': 1,
#  'height basketball nets': 1,
#  'helmet': 1,
#  'helmets': 1,
#  'hill': 1,
#  'historical preservation': 1,
#  'homeless': 5,
#  'homeless shelter': 2,
#  'homeless survival/hygiene kits': 1,
#  'house': 1,
#  'housing': 2,
#  'housing first': 1,
#  'hoyt': 2,
#  'hoyt field': 1,
#  'hoyt field tennis courts improvements': 1,
#  'hoyt softball field': 1,
#  'hubway': 5,
#  'hubway station': 1,
#  'human': 1,
#  'huron ave': 2,
#  'huron avenue': 1,
#  'idea': 1,
#  'ideas fair': 1,
#  'improvements': 2,
#  'inclusive playground equipment proposal': 1,
#  'influences': 1,
#  'injection facility': 1,
#  'inman': 1,
#  'inman square': 3,
#  'inman square bike friendly': 1,
#  'inspire the next generation': 1,
#  'installation': 1,
#  'instruments': 1,
#  'integrated accessible water play space': 1,
#  'internet': 1,
#  'intersection': 9,
#  'intersection of harvard street & moore street': 1,
#  'intersections': 3,
#  'iotnet network': 1,
#  'issue': 1,
#  'jade chain': 2,
#  'jcdecaux': 1,
#  'jfk park': 1,
#  'joan lorentz': 1,
#  'kendall sq': 1,
#  "kid's park": 1,
#  'kids': 2,
#  'kind': 1,
#  'kinetic sculpture': 1,
#  'kingsley park': 1,
#  'kirkland': 1,
#  'kitchen': 1,
#  'kits': 1,
#  'kurzweil': 1,
#  'lake st': 1,
#  'lakeview avenue': 1,
#  'landscaping opportunity': 1,
#  'lane': 1,
#  'lanes': 1,
#  'language class': 1,
#  'laptops': 1,
#  'laundry room': 1,
#  'lawn': 1,
#  'learning center': 1,
#  'learning disabilities': 1,
#  'leavs': 1,
#  'lechmere': 1,
#  'lending': 1,
#  'leverett circle': 1,
#  'libraries': 6,
#  'library': 7,
#  'library hour expansion': 1,
#  'life': 2,
#  'light': 4,
#  'lighting': 1,
#  'lights': 8,
#  'linear park': 1,
#  'lines': 1,
#  'litter disposal receptacles': 1,
#  'locations': 1,
#  'lock boxes': 1,
#  'lockers': 1,
#  'locks': 1,
#  'lorentz playground': 1,
#  'loughrey walkway': 1,
#  'lowell': 1,
#  'lowell park': 1,
#  'lyft': 1,
#  'magazine beach': 2,
#  'magee st cambridge community center building': 1,
#  'make science bridge bike friendly': 1,
#  'marcella st': 1,
#  'marie ave': 1,
#  'marijuana dispensary': 1,
#  'marker': 1,
#  'mass': 3,
#  'mass ave': 11,
#  'mass ave median beautification': 1,
#  'mass avenue': 1,
#  'massachusetts no idling signage': 1,
#  'massav': 1,
#  'masterplan': 1,
#  'median': 1,
#  'median strip': 1,
#  'meditation center': 1,
#  'memorial drive': 4,
#  'memorial drive: safer road': 1,
#  'minorities': 1,
#  'mirror': 1,
#  'mist sprinklers': 1,
#  'mit': 2,
#  'mobility': 1,
#  'monopoly': 1,
#  'moore weight room': 1,
#  'moss walls': 1,
#  'motion': 1,
#  'mr.': 1,
#  'mt': 1,
#  'music stage': 1,
#  'nap pods': 1,
#  'narcan': 1,
#  'need': 1,
#  'neighborhood': 1,
#  'neighborhood libraries': 1,
#  'neighborhoods': 1,
#  'new playground': 1,
#  'new youth center vans': 1,
#  'newtowne court': 1,
#  'no frills dog park': 1,
#  'north cambridge': 3,
#  'north mass ave': 1,
#  'north point pedestrian': 1,
#  'old park structures': 1,
#  'one': 1,
#  'opening': 1,
#  'opioid trafficking campaign': 1,
#  'outdoor fitness gym': 1,
#  'outdoor stage': 1,
#  'outdoor volleyball net system': 1,
#  'outdoor waterpark': 1,
#  'overhanging tree branches': 1,
#  'oxford street': 1,
#  'paine playground': 1,
#  'painting center bike lanes': 1,
#  'panels': 2,
#  'pannier': 1,
#  'park': 5,
#  'park benches': 1,
#  'parking': 2,
#  'parking lot': 1,
#  'parking lots': 1,
#  'parking meters': 4,
#  'parking spots': 1,
#  'parklets': 1,
#  'parks': 11,
#  'part': 2,
#  'participants': 1,
#  'parts': 1,
#  'party line': 1,
#  'patches': 1,
#  'path': 1,
#  'path improvements': 1,
#  'paths': 1,
#  'paul dudley white': 2,
#  'pearl street': 1,
#  'pedestrian': 2,
#  'pedestrian bridge': 1,
#  'pedestrian light': 1,
#  'pedestrian overpasses': 1,
#  'pedestrian safety': 1,
#  'pedestrian safety initiative': 1,
#  'pedestrians': 3,
#  'pedstrian': 1,
#  'people': 7,
#  'performance stage': 1,
#  'pet waste disposal': 1,
#  'phone': 1,
#  'phone app': 1,
#  'phone charging stations': 1,
#  'pick up': 1,
#  'pick-up spots': 1,
#  'pickup': 1,
#  'picnic table(s)': 1,
#  'planting trees': 1,
#  'playground': 5,
#  'playground features': 1,
#  'playgrounds': 1,
#  'pleasant st': 1,
#  'poles': 1,
#  'police oversight board': 1,
#  'police substation': 1,
#  'pool': 1,
#  'pool players': 1,
#  'port a potty': 1,
#  'porta-potties': 1,
#  'porter': 2,
#  'porter square': 4,
#  'porter square t exit': 1,
#  'porter street': 1,
#  'portland loo': 1,
#  'portraits': 1,
#  'power': 1,
#  'power lines': 1,
#  'ppl': 1,
#  'pre-teens': 1,
#  'preserve alewife river reservation': 1,
#  'problems': 1,
#  'project hockey': 1,
#  'project status': 1,
#  'promote walking': 1,
#  'prospect st bike lanes': 1,
#  'prune': 1,
#  'pub purpose': 1,
#  'public art': 1,
#  'public housing capital improvement apprenticeship program': 1,
#  'public interest incentives': 1,
#  'public schools': 1,
#  'pumps': 1,
#  'putnam': 2,
#  'putnam ave': 1,
#  'putnam st': 1,
#  'quadrandle': 1,
#  'quadrangle side': 1,
#  'rabbit bow hunting': 1,
#  'radios': 1,
#  'rail trail': 1,
#  'rail trail bike connector': 1,
#  'railway crossing': 1,
#  'rain gardens': 1,
#  'rain shelters': 1,
#  'random acts of street furniture': 1,
#  'rapid transit': 1,
#  'raymond park safety': 1,
#  'recreation for youth': 1,
#  'recycle bins': 1,
#  'recycling': 2,
#  'recycling barrel': 1,
#  'recycling bins': 1,
#  'red light avoidance': 1,
#  'red light cameras': 1,
#  'red light runners': 1,
#  'red line': 1,
#  'redevelopment': 1,
#  'removal': 1,
#  'rental': 1,
#  'rental coops': 1,
#  'repair nets': 1,
#  'replacement trees': 2,
#  'residents': 2,
#  'resilience': 1,
#  'resources': 1,
#  'resting pods': 1,
#  'resurfacing': 2,
#  'richdale ave': 1,
#  'ride': 1,
#  'ride share': 1,
#  'ride share pickup areas': 1,
#  'rindge ave': 1,
#  'rindge avenue': 1,
#  'river st': 2,
#  'river street': 1,
#  'riverbend park': 1,
#  'road lights': 1,
#  'roads': 2,
#  'roadways': 1,
#  'roberts': 1,
#  'roberts road': 1,
#  'rodent remediation': 1,
#  'roof garden': 1,
#  'roof top': 1,
#  'route 28': 1,
#  'route 69': 1,
#  'rules': 1,
#  'safer crosswalks for mass ave': 1,
#  'safety': 1,
#  'saint peters field': 1,
#  'salary increase': 1,
#  'salt shed': 1,
#  'sand volleyball court': 1,
#  'school': 1,
#  'school buildings': 1,
#  'school toilets': 1,
#  'schoolers': 1,
#  'schools': 6,
#  'science center plaza': 1,
#  'scooter locks': 1,
#  'scooters': 1,
#  'seating': 1,
#  'seating area': 1,
#  'secondary': 1,
#  'section': 1,
#  'sections': 1,
#  'selfie spots': 1,
#  'senior center': 1,
#  'seniorctr & cityhall': 1,
#  'seniors': 1,
#  'sennet park': 1,
#  'sennott park': 2,
#  'sex education': 1,
#  'shade': 1,
#  'shade structure': 1,
#  'shade structures': 1,
#  'shadora gray': 1,
#  'sheep day': 1,
#  'shelter': 1,
#  'shelters': 1,
#  'shoupista': 1,
#  'showers': 1,
#  'shuttle bus': 1,
#  'side': 5,
#  'sides': 1,
#  'sidewalk': 4,
#  'sidewalk benches': 1,
#  'sidewalk improvement': 1,
#  'sidewalk lighting': 1,
#  'sidewalk listening booth': 1,
#  'sidewalk path': 1,
#  'sidewalk pothole repair': 1,
#  'sidewalk ramp': 1,
#  'sidewalks': 8,
#  'sidney': 1,
#  'signage': 2,
#  'signals': 1,
#  'signs': 4,
#  'silva park': 1,
#  'sites': 2,
#  'sleeping bags': 1,
#  'slide': 1,
#  'smokers': 1,
#  'snow emergency': 1,
#  'snow removal': 2,
#  'snowmelt system': 1,
#  'soccer fields': 1,
#  'software': 1,
#  'solar panels': 4,
#  'space': 2,
#  'sparks street': 2,
#  'speakers': 1,
#  'speed bumps': 1,
#  'speed cameras': 1,
#  'speed hump': 1,
#  'spittons': 1,
#  'splash pad': 1,
#  'sports equipment': 1,
#  'spray deck': 1,
#  'sprinklers': 1,
#  "st. mary's": 1,
#  "st. peter's field": 2,
#  "st. peter's fields": 1,
#  'stage': 1,
#  'stairs': 1,
#  'standish': 1,
#  'state': 1,
#  'station': 2,
#  'stations': 1,
#  'stem': 1,
#  'stop sign': 2,
#  'stop signs': 1,
#  'storage area': 1,
#  'storefronts': 1,
#  'storm shelters': 1,
#  'street': 4,
#  'street art': 1,
#  'street furniture': 1,
#  'street mural': 1,
#  'street recycling': 1,
#  'street signs upgrade': 1,
#  'street trees': 1,
#  'street utility': 1,
#  'streets': 4,
#  'streets pilot': 1,
#  'stretch': 1,
#  'stretch pb': 1,
#  'student center': 1,
#  'student s': 1,
#  'students': 2,
#  'styrofoam': 1,
#  'substance abuse prevention': 1,
#  'summer pool': 1,
#  'sun': 1,
#  'sunscreen booths to protect against melanoma': 1,
#  'sunscreen dispensers': 1,
#  'supplement': 1,
#  'surfaces': 1,
#  'swamp': 1,
#  'swap parking': 1,
#  'swim park': 1,
#  'switch parking': 1,
#  't improvements': 1,
#  't stations': 1,
#  'tables': 1,
#  'technology': 1,
#  'technology trail': 1,
#  'temporary detention centers': 1,
#  'tennis courts': 1,
#  'tent encampment': 1,
#  'the homeless': 1,
#  'the industrial revolution': 1,
#  'thirsty trees': 1,
#  'thorndike': 1,
#  'tiles': 1,
#  'tinyhomes': 1,
#  'tobin playground': 1,
#  'tobin school': 1,
#  'toilets': 1,
#  'tokyo restaurant site': 1,
#  'tour buses': 1,
#  'toys': 1,
#  'traffic': 2,
#  'traffic calming': 1,
#  'traffic control': 1,
#  'traffic flow': 1,
#  'traffic light': 3,
#  'traffic lights': 2,
#  'traffic mirrors': 2,
#  'traffic violations': 1,
#  'trail': 1,
#  'train stations': 1,
#  'trampolines': 1,
#  'trash': 1,
#  'trash cans': 4,
#  'trash collection units': 1,
#  'trash compacters': 1,
#  'trash containers': 1,
#  'trash receptacles': 1,
#  'trash wheel boat': 1,
#  'travel lanes': 1,
#  'tree canopy': 1,
#  'tree house': 1,
#  'tree map': 1,
#  'trees': 8,
#  'tricycle use': 1,
#  'tulips': 1,
#  'tunnel': 1,
#  'twin city plaza basketball courts': 1,
#  'uber': 1,
#  'units': 1,
#  'universal access park': 1,
#  'unused public wells': 1,
#  'update glacken': 1,
#  'upgrade': 2,
#  'upkeep': 1,
#  'upper schools': 1,
#  'urban heat island': 1,
#  'urban heat schmiland': 1,
#  'urbanism fund': 1,
#  'use': 1,
#  'utility lines': 1,
#  'vail court': 1,
#  'vending machines': 2,
#  'video game center': 2,
#  'vintage': 1,
#  'visibility': 1,
#  'voter registration': 1,
#  'walden street': 1,
#  'walk light': 1,
#  'walkable central square': 1,
#  'walking': 1,
#  'walking path': 1,
#  'walkway light': 1,
#  'warren streets': 1,
#  'water': 2,
#  'water bottle': 1,
#  'water bottle station for basketball players': 1,
#  'water collection': 1,
#  'water fountain': 2,
#  'water fountains': 4,
#  'water spray': 1,
#  'water stations': 1,
#  'watertown': 1,
#  'waverly': 2,
#  'way bike path signage': 1,
#  'way stops': 1,
#  'wayfinding signage': 1,
#  'weekend backpack program': 1,
#  'western': 1,
#  'western ave': 3,
#  'wheelchairs': 1,
#  'whimsy': 1,
#  'white roof project': 1,
#  'whole foods': 1,
#  'wi-fi': 1,
#  'wider park': 1,
#  'wifi': 6,
#  'wifi hotspots': 1,
#  'windsor street': 1,
#  'winter tennis court bubble': 1,
#  'women': 1,
#  'wood chips': 1,
#  'workers': 1,
#  'workout area': 1,
#  'workout equipment': 1,
#  'yield': 1,
#  'young people': 1,
#  'youth center': 1}
